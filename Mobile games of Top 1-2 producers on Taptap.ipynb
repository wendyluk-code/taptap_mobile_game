# %%
import requests 
import bs4 as bs 

from time import sleep
from time import time
from random import randint

# %% [markdown]
# # Top 1_0 Tencent 腾讯

# %%
text = '''<!doctype html>
<html>
<head>
    <meta charset="utf-8">
    <meta name="renderer" content="webkit">
    <meta name="force-rendering" content="webkit">
    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
    <meta name="theme-color" content="#009BAA">
                <title>腾讯 - 旗下游戏 | TapTap 发现好游戏</title>
    <meta name="keywords" content="腾讯,腾讯旗下游戏,腾讯都有哪些游戏">
    <meta name="description" content="想要知道腾讯都有哪些游戏，腾讯旗下游戏的介绍，就来 TapTap 的腾讯专区一看究竟吧。">
        <link rel="search" type="application/opensearchdescription+xml" href="https://www.taptap.com/opensearch-v2.xml" title="TapTap">
    <meta name="apple-itunes-app" content="app-id=1444595166">
        <link rel="canonical" href="https://www.taptap.com/developer/1012/apps">
    <meta name="csrf-token" content="jaPM7LZETieHlEICuE7Q2nWEDoFsBgL66sflAKMa">
    <meta name="cookie-domain" content="www.taptap.com">
                        <meta name="tapad-lang" content="zh_CN">
        <meta name="tapad-store" content="cn">
    <meta name="lang" content="chs">

        <meta name="msvalidate.01" content="C12FFA5B4C661AB8C1E9F87AC3083C5D">
    <meta name="baidu-site-verification" content="6IjfeOZ9ud">
    <meta name="360-site-verification" content="bc27538a632d06a82201e38c43571cd9">

    <meta name="apple-mobile-web-app-title" content="TapTap">
            <meta name="applicable-device" content="pc">
        <meta http-equiv="Cache-Control" content="no-transform">

    <link rel="dns-prefetch" href="https://assets.tapimg.com">
    <link rel="dns-prefetch" href="https://video2.tapimg.com">
    <link rel="dns-prefetch" href="https://img.tapimg.com">
    <link rel="dns-prefetch" href="https://img2.tapimg.com">
    <link rel="dns-prefetch" href="https://img3.tapimg.com">
            <link rel="shortcut icon" href="/favicon.ico">
    <link rel="apple-touch-icon" sizes="60x60" href="https://assets.tapimg.com/img/touch-icon-iphone.png">
    <link rel="apple-touch-icon" sizes="76x76" href="https://assets.tapimg.com/img/touch-icon-ipad.png">
    <link rel="apple-touch-icon" sizes="120x120" href="https://assets.tapimg.com/img/touch-icon-iphone-retina.png">
    <link rel="apple-touch-icon" sizes="152x152" href="https://assets.tapimg.com/img/touch-icon-ipad-retina.png">

            
    
    <link href="https://assets.tapimg.com/style/base.css?20190129" rel="stylesheet">

        <link href="https://assets.tapimg.com/css/app-0caafd7289.css" rel="stylesheet">
                        <link rel="alternate" hreflang="zh-Hans-cn" href="https://www.taptap.com/developer/1012/apps">
        <link rel="alternate" hreflang="zh-Hant-hk" href="https://www.taptap.com/developer/1012/apps?region=hk">
    <link rel="alternate" hreflang="en-us" href="https://www.taptap.com/developer/1012/apps?region=us">
    <link rel="alternate" hreflang="ja-jp" href="https://www.taptap.com/developer/1012/apps?region=jp">
    <link rel="alternate" hreflang="ko-kr" href="https://www.taptap.com/developer/1012/apps?region=kr">
                                <script src="https://zz.bdstatic.com/linksubmit/push.js"></script><script async="" src="https://assets.tapimg.com/scripts/sensorsdata.min.js" charset="UTF-8"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script>
        function blade(_){return _;}
        window.tapEnv = blade({"user":{"id":null,"is_deactivated":false},"user_settings":null,"action":{"should_certify":null,"must_certify":null,"must_exam":null,"should_exam":null,"publish_alert":null,"bound_weixinserve":null},"browser":{"inApp":false},"lang":"chs","locale":"zh_CN","tapad":{"lang":"zh_CN","store":"cn"},"log_params":{"common":{"XUT":null}},"config":{"bot_detect":true}}) || {};
    </script>
        <script src="https://assets.tapimg.com/js/lang_chs-0fb72ffc2f.js"></script>
        <script src="https://assets.tapimg.com/js/base-610f63b160.js"></script>
        
        <!--[if lt IE 9]>
        <script src="https://assets.tapimg.com/scripts/html5shiv.min.js"></script>
        <script src="https://assets.tapimg.com/scripts/respond.min.js"></script>
        <link rel="respond-proxy" id="respond-proxy" href="https://assets.tapimg.com/cross-domain/respond-proxy.html"/>
        <link rel="respond-redirect" id="respond-redirect" href="/build/cross-domain/respond.proxy.gif"/>
        <script src="/build/cross-domain/respond.proxy.js"></script>
        <![endif]-->

                <script src="https://assets.tapimg.com/js/app-f7ab952bcc.js"></script>
        <script src="https://assets.tapimg.com/js/mixin-fab8d1d875.js"></script>
        </head>
<body class="app-body
            
            pc
            
                                ">

                
                
                <nav class="navbar navbar-default" id="navbar">
    <div class="container">
        <div class="navbar-header">
            <button type="button" class="navbar-toggle collapsed" data-taptap-slide="nav" data-target="#navbarSlide" aria-expanded="false">
                <span class="sr-only">Toggle navigation</span>
                <span class="icon-bar"></span>
                <span class="icon-bar"></span>
                <span class="icon-bar"></span>
            </button>
            <a class="navbar-brand" href="https://www.taptap.com">
            </a>
            <a href="https://www.taptap.com/mobile" class="navbar-header-xz">
                                    <i class="taptap-icon icon-mobile-download"></i>
                            </a>
        </div>
        <div class="navbar-collapse" id="navbarSlide">
            <div class="narbar-collapse-btn">
                <button class="btn btn-default" data-taptap-slide="nav" data-target="#navbarSlide" type="button">
                    <i class="taptap-icon icon-arrow-left"></i>
                </button>
            </div>
            <ul class="nav navbar-nav navbar-left">
                <li>
                    <a href="https://www.taptap.com">首页</a>
                </li>
                <li>
                                            <a href="https://www.taptap.com/top/download">排行榜</a>
                                    </li>
                <li>
                    <a href="https://www.taptap.com/review/new">安利墙</a>
                </li>
                <li>
                    <a href="https://www.taptap.com/categories">发现</a>
                </li>
                <li>
                    <a href="https://www.taptap.com/forum/hot">论坛</a>
                </li>
                                                                                        <li>
                        <a href="https://www.taptap.com/video">视频</a>
                    </li>
                            </ul>
        </div>
        <div class="navbar-mask" data-taptap-slide="nav" data-target="#navbarSlide"></div>
        <ul class="nav navbar-nav navbar-right">
            <li>
                <button class="navbar-search btn btn-default js-emit" tap-event="search.show" data-taptap-nav="search" type="button">
                    <i class="icon-font icon-searchnew"></i>
                </button>
            </li>
            <li class="dropdown navbar-notice hide">
                <button id="taptap-notification" class="btn btn-default taptap-notice-bell" data-taptap-ajax="notification" data-message-total="条新消息" type="button" data-unread="0" data-get-unread-total-url="https://www.taptap.com/ajax/notification/un-read-total" data-url="https://www.taptap.com/ajax/notification" onclick="ga('send','event','Topbar','Notification','MenuExpand')">
    <i class=""></i>
</button>
                <div class="taptap-notice-widget" id="ajaxNotifications" style="display: none;">
    <div class="notice-widget-loading" data-taptap-ajax-notification="loading">
        <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="">
    </div>
</div>
            </li>
            <li class="dropdown navbar-user">
                <a href="https://www.taptap.com/auth/login" class="img-circle avatar-wrap" rel="nofollow" role="button" aria-haspopup="true" aria-expanded="false">
                    <img src="https://img.tapimg.com/market/images/22f1196f825298281376608459bfa7fe.png" alt="">
                </a>
                <input type="hidden" value="个人中心" id="dashboard">
                <input type="hidden" value="我的关注" id="my_following">
                <input type="hidden" value="我的收藏" id="my_collections">
                <input type="hidden" value="我的订单" id="my_orders">
                <input type="hidden" value="篝火计划" id="campfire">
                <input type="hidden" value="浏览历史" id="browse_history">
                <input type="hidden" value="我的草稿" id="draft_box">
                <input type="hidden" value="开发者中心" id="developer_center">
                <input type="hidden" value="登出" id="logout">
                <input type="hidden" value="解冻账号" id="activate">
            </li>
        </ul>
                <form class="navbar-form" id="search" role="search" method="get" action="https://www.taptap.com/search">
            <div class="form-group">
              <button type="submit" class="btn btn-default">
                <i class="icon-font icon-search2"></i>
              </button>
                <input type="text" class="form-control js-emit search-input" tap-event="click:search.show,change:search.apps,keydown:search.keydown" autocomplete="off" id="search-kw" name="kw" value="" placeholder="搜索...">
            </div>
                                        <div class="taptap-search " style="display: none;">
        <div class="supports">
        <section class="history">
            <header>
                历史搜索
                <span class="clear-history">
                    <button class="js-emit" tap-event="search.clear-history" type="button">清空</button>
                </span>
            </header>
            <div class="list">
                <ul class="list-unstyled">
                    <li class="loading">
                        <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading">
                    </li>
                </ul>
            </div>
        </section>
        <section class="hot-word">
            <header>热门搜索</header>
            <div class="list">
                <ul class="list-unstyled">
                </ul>
            </div>
        </section>
        <section class="results show">
      <div class="loading">
      <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading">
    </div>
  </section>
    </div>
</div>
                    </form>
    </div>
</nav>
                        <section class="taptap-breadcrumb">
            <div class="container">
                <div class="row">
                    <ol class="breadcrumb">
                        <li><span>你的位置:</span></li>
                        <li><a href="https://www.taptap.com">首页</a></li>
                        
    <li><a href="https://www.taptap.com/developer/1012">腾讯</a></li>
    <li class="active"><span>厂商游戏</span></li>

                    </ol>
                    <span class="breadcrumb-end"></span>
                </div>
            </div>
        </section>
        
            <div class="container">
        <div class="row">
            <div class="col-sm-12">
                <section class="app-category-list">
                    <div class="section-title">
                        <h1>厂商游戏</h1>
                    </div>
                    <div class="tab-content">
                        <div class="tab-pane active" role="tab" id="apps">
                            <div class="taptap-app-list" id="appList">
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/85845" data-taptap-url="taptap://taptap.com/app?app_id=85845&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/377b8418c41cf9c0ef49a8e57baf3687_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/377b8418c41cf9c0ef49a8e57baf3687_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="雪鹰领主" title="雪鹰领主" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/85845" data-taptap-url="taptap://taptap.com/app?app_id=85845&amp;style=0" title="雪鹰领主">
            <h4 class="flex-text">雪鹰领主</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/rpg" data-taptap-url="taptap://taptap.com/app_tag?tag=角色扮演" class="taptap-link">角色扮演</a>
                        <span class="caption-label-rating pull-right">
                <span>5.5</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/72784" data-taptap-url="taptap://taptap.com/app?app_id=72784&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/2d6079cb5745dbc914c863032e7912a3_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/2d6079cb5745dbc914c863032e7912a3_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="FIFA足球世界" title="FIFA足球世界" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app
img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="" data-taptap-ajax-more="loading" style="display: none;">
</section>
                                                    </div>
                    </div>
                </section>
            </div>
        </div>
    </div>

                            <footer class="footer">
    <div class="container">
        <div class="row">
            <div class="col-sm-12 clearfix">
                <div class="pull-right">
                    <p>Contact Us</p>
                    <ul class="list-inline">
                        <li>
                            <a class="icon-font ic_facebook" href="https://www.facebook.com/gametaptap/" target="_blank" title="Facebook" rel="nofollow"></a>
                        </li>
                        <li>
                            <span class="icon-font ic_wechat" title="微信"></span>
                            <div>
                                <span class="thumbnail">
                                    <img src="https://img.tapimg.com/market/images/c4bf2701e3ee9993e1ee0b8222480a35.jpg" alt="">
                                </span>
                            </div>
                        </li>
                        <li>
                            <span class="icon-font ic_qq" title="QQ"></span>
                            <div>
                                <span class="thumbnail">官方QQ群: 780255342</span>
                            </div>
                        </li>
                        <li>
                            <a class="icon-font ic_zhihu" href="https://zhuanlan.zhihu.com/taptap" target="_blank" title="知乎" rel="nofollow"></a>
                        </li>
                        <li>
                            <a class="icon-font ic_sina" href="http://weibo.com/taptapgames" target="_blank" title="微博" rel="nofollow"></a>
                        </li>
                        <li>
                            <span class="icon-font ic_mail" title="邮箱"></span>
                            <div>
                                <span class="thumbnail">
                                    合作邮箱: <a href="mailto:cooperation@taptap.com" rel="nofollow">cooperation@taptap.com</a>
                                </span>
                            </div>
                        </li>
                    </ul>
                                                                        <p>官方活动</p>
                                            <div class="events-link">
                        <span class="link">
                            <a href="https://www.taptap.com/events/3rd-anniversary" rel="nofollow" onclick="ga('send','event','bottom-entry','click','thirdAnniversary');sa.click({position: '页脚'}, event)">TapTap 三周年</a>
                        </span>
                        <span class="link">
                            <a href="https://www.taptap.com/campfire" rel="nofollow" onclick="ga('send','event','bottom-entry','click','campfire');sa.click({position: '页脚'}, event)">篝火计划</a>
                        </span>
                        <span class="link">
                            <a href="https://www.taptap.com/events/3rd-anniversary/doodle" rel="nofollow" onclick="ga('send','event','bottom-entry','click','doodle2019');sa.click({position: '页脚'}, event)">涂鸦大赛</a>
                        </span>
                        <span class="link">
                            <a href="https://www.taptap.com/game-awards2018" rel="nofollow" onclick="ga('send','event','bottom-entry','click','gameAwards2018');sa.click({position: '页脚'}, event)">2018年度游戏大赏</a>
                        </span>
                    </div>
                                                        </div>
                <div class="footer-left">
                    <div class="footer-left-header">
                        <span class="left-header-logo">
                            <img src="https://assets.tapimg.com/img/ic_logocn@3x.png?20190610" alt="TapTap 中国" title="TapTap 中国">
                        </span>
                        <div class="dropdown">
                                                                                                                <button id="regionSelect" type="button" class="btn btn-link" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                                中文 (简体)
                                <span class="caret"></span>
                            </button>
                            <ul class="dropdown-menu" aria-labelledby="regionSelect">
                                <li><span class="dropdown-tips">选择语言</span></li>
                                                                    <li class="active">
                                            <a href="https://www.taptap.com/set-region?region=cn" class="js-http-post" rel="nofollow">中文 (简体)</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=tw" class="js-http-post" rel="nofollow">中文 (繁體)</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=us" class="js-http-post" rel="nofollow">English</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=jp" class="js-http-post" rel="nofollow">日本語</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=kr" class="js-http-post" rel="nofollow">한국어</a>
                                    </li>
                                                            </ul>
                        </div>
                        <p class="links">
                            <span class="link">
                                <a href="https://www.taptap.com/developer" rel="nofollow">开发者中心</a>
                            </span>
                                                            <span class="link">
                                    <a href="https://www.taptap.com/developer/developer-distribution-agreement" rel="nofollow">开发者协议</a>
                                </span>
                                                        <span class="link">
                                <a href="https://www.taptap.com/ads" rel="nofollow">广告投放</a>
                            </span>
                            <span class="link">
                                <a href="https://www.taptap.com/about-us" rel="nofollow">关于我们</a>
                            </span>
                            <span class="link">
                                <a href="https://www.taptap.com/hr" rel="nofollow">加入我们</a>
                            </span>
                                                        <span class="link">
                                <a href="https://www.taptap.com/user-verification" rel="nofollow">用户认证</a>
                            </span>
                                                    </p>
                    </div>
                    <p>Discover Superb Games.</p>
                    <span>
                        <span>Copyright © 2019 <a href="https://www.taptap.com">TapTap</a>. All rights Reserved.</span>
                        <br>
                        <span>适龄提示: 本公司产品适合 10 周岁以上玩家使用</span>
                        <span>&nbsp;<a href="https://www.taptap.com/taptapjh" target="_blank" rel="nofollow">未成年人家长监护</a>&nbsp;&nbsp;                            <a href="https://www.taptap.com/privacy-policy" rel="nofollow">隐私政策</a>&nbsp;&nbsp;
                            <a href="https://www.taptap.com/copyright" rel="nofollow">侵权投诉</a>                         </span>
                        <br>
                                                <span>
                            <a href="http://www.beian.miit.gov.cn/" target="_blank" rel="nofollow">沪ICP备16012525号-1</a>&nbsp;&nbsp;
                            <a href="/license/www.html">沪网文(2019)3544-255号&nbsp;&nbsp;</a>
                        </span>
                        <br>
                                                <span class="manage">经营许可证编号: 沪B2-20170322</span>易玩（上海）网络科技有限公司
                        <br>
                        <span>公司地址: 上海市静安区万荣路 700 号 A3 202</span>
                    </span>
                </div>
            </div>
                            <div class="col-sm-12 clearfix">
                    <span class="record-filing">
                        <a target="_blank" href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=31010402003255" rel="nofollow">
                            <img src="https://img.tapimg.com/market/images/d0289dc0a46fc5b15b3363ffa78cf6c7.png">
                            <p>沪公网安备 31010402003255号</p>
                        </a>
                        <a target="_blank" href="http://sq.ccm.gov.cn:80/ccnt/sczr/service/business/emark/toDetail/35EE6340BAC97151E0530140A8C0E25A" rel="nofollow">
                            <img src="https://img.tapimg.com/market/images/d839a60d8749eca93b9ca669583e65f4.png">
                            <p>互联网文化经营单位</p>
                        </a>
                        <a target="_blank" href="http://www.shjbzx.cn/" class="report" title="上海市互联网违法和不良信息举报中心" rel="nofollow">
                            <img src="https://img.tapimg.com/market/images/205fb1dc7c6c602e57c1b8e6477529d4.png">
                        </a>
                                            </span>
                </div>
                    </div>
    </div>
</footer>
        
        
                                    <section class="modal fade taptap-modal global-tip-modal" tabindex="-1" role="dialog" id="global-tip-modal">
    <div class="modal-dialog">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
                <h4 class="modal-title" data-default-text="提示">提示</h4>
            </div>
            <div class="modal-body">
                <p></p>
            </div>
            <div class="modal-footer">
                <button class="btn btn-primary" data-default-text="确定">确定</button>
                <button class="btn btn-default" data-dismiss="modal" data-default-text="取消">取消</button>
            </div>
        </div>
    </div>
</section>
    <div class="modal fade taptap-modal taptap-alert taptap-alert-success" tabindex="-1" role="dialog" id="operation-state-modal">
  <div class="modal-dialog">
    <div class="modal-content">
      <div class="modal-body">
        <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
        <div class="alert-logo success">
          <span></span>
        </div>
        <p class="alert-message-title"></p>
        <p class="alert-message single-line">成功</p>
        <div class="html-render"></div>
              </div>
    </div>
  </div>
</div>
    <div class="taptap-simple-alert" id="simpleAlertModal">
  <button type="button"><span aria-hidden="true">×</span></button>
  <span class="alert-logo fail">
    <i class="icon-font icon-error"></i>
    <p class="alert-message">trans('interface.word.success')</p>
  </span>
</div>
    <section class="taptap-button-top" data-taptap-widgets="container" data-taptap-go="top" style="display: block;">
    <i class="icon-font icon-stick"></i>
</section>
                <section class="taptap-bottom-banner collapse" id="bottomBanner">
    <div class="container">
        <div class="row">
            <div class="col-sm-12 clearfix">
                <div class="bottom-banner-left">
                    <img src="https://img.tapimg.com/market/images/dcaacad6231ac7003cf1b62b6643c450.png" alt="">
                </div>
                <div class="bottom-banner-center">
                    <ul class="list-unstyled">
                                                <li>
                            <span></span>
                            <p>一天一款全球精品游戏推荐，活跃的玩家交流社区</p>
                        </li>
                                                <li>
                            <span></span>
                            <p>只收录官方包，不联运，支持安卓正版游戏购买</p>
                        </li>
                                                <li>
                            <span></span>
                            <p> 倡导真实评分评价，排行榜单来自玩家真实反馈</p>
                        </li>
                                            </ul>
                    <p>
                        <span>TapTap</span>
                        <br>
                        发现好游戏
                    </p>
                </div>
                <div class="bottom-banner-right">
                    <button class="close" type="button" data-toggle="collapse" data-target="#bottomBanner" data-taptap-cookie-set="bottom_banner_hidden" data-days="365" data-value="1">
                        <i class="taptap-icon icon-times"></i>
                    </button>
                    <div class="banner-right-btns">
                        <button class="btn btn-default taptap-button-hollow" data-taptap-modal="qrcode">
                            二维码下载
                            <span data-taptap-qrcode="generate" data-url="https://d.taptap.com/latest"><canvas width="100" height="100"></canvas></span>
                        </button>
                        <a href="https://d.taptap.com/latest" class="btn btn-success" onclick="ga('send', 'event', 'Client', 'BottombarDownload');sa.perform({action: 'Download', type: 'BottomBanner'});" rel="nofollow">
                            <span class="desktop">免费下载</span>
                            <span class="mobile">下载</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div>
</section>
                    <section class="modal fade taptap-modal login-tips" tabindex="-1" role="dialog" aria-labelledby="loginTipsModal" id="loginTipsModal">
    <div class="modal-dialog">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
                <h4 class="modal-title">温馨提示</h4>
            </div>
            <div class="modal-body">
                <p>请先<a href="/auth/login" rel="nofollow">登录</a>后，再进行操作</p>
            </div>
        </div>
    </div>
</section>                <section class="modal fade taptap-modal login-form" tabindex="-1" role="dialog" aria-labelledby="loginFormModal" id="loginFormModal">
    <div class="modal-dialog">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
                <h4 class="modal-title"></h4>
            </div>
            <div class="modal-body auth-main">
                <div class="auth-main-body login">

                </div>

            </div>
        </div>
    </div>
</section>
        <section class="modal fade taptap-modal phone-captcha-modal" tabindex="-1" role="dialog" aria-labelledby="phoneCaptcha" id="phoneCaptcha">
    <div class="modal-dialog ">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div class="modal-content">
                <h5>请输入短信验证码</h5>
                                    <div id="phone-captcha" class="phone-captcha">
                        <input type="text" maxlength="1" autofocus="" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                    </div>
                                <div class="loading"><img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading"></div>
                <div class="error"></div>
            </div>
            <div class="modal-footer">
                <div class="code-tip" data-taptap-has-send="true">
                    <p>短信验证码已发送至<span id="phone-number">+86xxxxxxxxxxxx</span></p>
                    <p><span id="count" class="count">59</span>&nbsp;秒后可重新发送</p>
                </div>
                <div class="code-tip" data-taptap-has-send="false">
                    <p class="send-again-container">
                        <span class="send-loading"><img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading"></span>
                        <span id="send-again" class="count" tap-event="sendPhoneCaptcha">重新发送</span>
                    </p>
                </div>
            </div>
        </div>
    </div>
</section>
            
            <div class="modal fade taptap-modal user-certification" tabindex="-1" role="dialog" id="verifyIdcardModal">
  <div class="modal-dialog">
    <div class="modal-content">
      <form action="" method="post" id="verifyIdcardForm">
        <input type="hidden" name="_token" value="jaPM7LZETieHlEICuE7Q2nWEDoFsBgL66sflAKMa">
        <div class="modal-header">
          <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
          <h4 class="modal-title">实名信息提交</h4>
        </div>
        <div class="modal-body">
          <div class="common-form-fields">
            <div class="common-form-basic-title">
              <h3><span>真实姓名</span></h3>
            </div>
            <p class="common-field">
              <input type="text" name="real_name" class="common-form-text" id="real-name">
            </p>
            <div class="common-form-basic-title">
              <h3><span>身份证号码</span></h3>
            </div>
            <p class="common-field">
              <input type="text" name="idcard" class="common-form-text" id="idcard-number">
            </p>
          </div>
          <p class="note">*请使用真实姓名及有效身份证号码进行实名信息提交<br>*身份信息提交后不可进行修改<br>*有意填写非本人身份信息者，被发现将对账号进行封禁处理<br>*如有疑问，可联系 TapTap 客服邮箱：kefu@taptap.com</p>
        </div>
        <div class="modal-footer">
          <button type="submit" class="btn btn-primary" data-url="https://www.taptap.com/ajax/profile/idcard" id="verify-submit">提交</button>
                  </div>
      </form>
    </div>
  </div>
</div>
                <script>
    (function (i, s, o, g, r, a, m) {
        i['GoogleAnalyticsObject'] = r;
        i[r] = i[r] || function () {
            (i[r].q = i[r].q || []).push(arguments)
        }, i[r].l = 1 * new Date();
        a = s.createElement(o),
            m = s.getElementsByTagName(o)[0];
        a.async = 1;
        a.src = g;
        m.parentNode.insertBefore(a, m)
    })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');

            ga('create', 'UA-73963350-1', 'auto');
    
    var browserName = "Other";
    var ua = window.navigator.userAgent;
    browserRegExp = {
        iOSSDK: /TapTapiOSSDK/,
        AndroidSDK: /TapTapAndroidSDK/,
        Sogou: /SE\s2\.X|SogouMobileBrowser/,
        Explorer2345: /2345Explorer|2345chrome|Mb2345Browser/,
        Liebao: /LBBROWSER/,
        Wechat: /MicroMessenger/,
        QQBrowser: /QQBrowser/,
        Baidu: /BIDUBrowser|baidubrowser|BaiduHD/,
        UC: /UBrowser|UCBrowser|UCWEB/,
        MiuiBrowser: /MiuiBrowser/,
        MobileQQ: /Mobile\/\w{5,}\sQQ\/(\d+[\.\d]+)/,
        Shoujibaidu: /baiduboxapp/,
        SamsungBrowser: /samsungbrowser/,
        Firefox: /Firefox/,
        Maxthon: /Maxthon/,
        Se360: /360SE/,
        Ee360: /360EE/,
        TheWorld: /TheWorld/,
        Weibo: /__weibo__/,
        NokiaBrowser: /NokiaBrowser/,
        Opera: /Opera|OPR\/(\d+[\.\d]+)/,
        Edge: /Edge/,
        QQLive: /QQLive(HD)?Browser/,
        Letv: /LetvClient/,
        Youku: /Youku/,
        AndroidBrowser: /Android.*Mobile\sSafari|Android\/(\d[\.\d]+)\sRelease\/(\d[\.\d]+)\sBrowser\/AppleWebKit(\d[\.\d]+)/i,
        IE: /Trident|MSIE/,
        TouTiao: /NewsArticle/,
        Chrome: /Chrome|CriOS/,
        Safari: /Version[|\/]([\w.]+)(\s\w.+)?\s?Safari|like\sGecko\)\sMobile\/\w{3,}$/,
    };

    if (window.tapEnv && window.tapEnv.browser && window.tapEnv.browser.inApp === true) {
        browserName = "InApp";
    } else {
        for (var i in browserRegExp) {
            if (browserRegExp[i].exec(ua)) {
                browserName = i;
                break;
            }
        }
    }

    if(window.tapEnv && window.tapEnv.user && window.tapEnv.user.id) {
        ga('set', 'dimension4', 'login');
    } else {
        ga('set', 'dimension4', 'guest');
    }

    if (browserName === "Other") {
        ga('set', 'dimension2', browserName + "-" + ua);
    } else {
        ga('set', 'dimension1', browserName);
    }

    ga('send', 'pageview');
</script>

<script>
(function (para) {
  var p = para.sdk_url, n = para.name, w = window, d = document, s = 'script', x = null, y = null;
  w['sensorsDataAnalytic201505'] = n;
  w[n] = w[n] || function (a) {
    return function () {
      (w[n]._q = w[n]._q || []).push([a, arguments]);
    }
  };
  var ifs = ['track', 'quick', 'register', 'registerPage', 'registerOnce', 'trackSignup', 'trackAbtest', 'setProfile', 'setOnceProfile', 'appendProfile', 'incrementProfile', 'deleteProfile', 'unsetProfile', 'identify', 'login', 'logout', 'trackLink', 'clearAllRegister', 'getAppStatus'];
  for (var i = 0; i < ifs.length; i++) {
    w[n][ifs[i]] = w[n].call(null, ifs[i]);
  }
  if (!w[n]._t) {
    x = d.createElement(s), y = d.getElementsByTagName(s)[0];
    x.async = 1;
    x.src = p;
    x.setAttribute('charset', 'UTF-8');
    y.parentNode.insertBefore(x, y);
    w[n].para = para;
  }
})({
  sdk_url: 'https://assets.tapimg.com/scripts/sensorsdata.min.js',
  heatmap_url: 'https://assets.tapimg.com/scripts/heatmap.min.js',
  name: 'sensorsSDK',
  web_url: 'https://sa.taptap.com/',
  server_url: 'https://sd.taptap.com/sa',
  show_log: false
});
window.sa = {
  post: function (props) {
    sensorsSDK.track('WebPost', props);
  },
  perform: function (props) {
    sensorsSDK.track('WebPerform', props);
  },
  click: function (props, event) {
    var target = event.target ? event.target : event.srcElement;
    target = target.closest('a');
    props.target_url = target.href;
    props.target_path = target.pathname
    sensorsSDK.track('$WebClick', props);
  },
  login: function (props) {
    sensorsSDK.track('WebLogin', props);
  }
};
(function () {
  var registerProps = {
    url: Tap.URI(location.href).pure().toString(),
    referer: document.referrer,
    path: location.pathname
  }
  if (Tap.browser.is('inApp')) {
    registerProps['client'] = Tap.env('browser.inAppPn', 'Unknown');
  }
  sensorsSDK.registerPage(registerProps);

  var user_id = $('meta[name=user_id]').attr('content');
  if (user_id) {
    sensorsSDK.login(user_id)
  } else {
    sensorsSDK.logout();
  }
  sensorsSDK.quick('autoTrack');
})();
</script>


<script>
        (function () {
        var tapUri = new Tap.URI();

        var bp = document.createElement('script');
        var curProtocol = window.location.protocol.split(':')[0];
        if (curProtocol === 'https') {
            bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
        }
        else {
            bp.src = 'http://push.zhanzhang.baidu.com/push.js';
        }
        var s = document.getElementsByTagName("script")[0];
        s.parentNode.insertBefore(bp, s);

                        var referrer = document.referrer;
        var bdUri;
        var bdsem;
        if (referrer) {
            bdUri = new Tap.URI(referrer);
            bdsem = bdUri.parse();
        }

        if ((tapUri.get('utm_source') == 'baidu' || tapUri.get('utm_medium') == 'sem' || (bdsem !== undefined && bdsem['path'] == 'baidu.php'))
            && Tap.browser.is('mobile')) {

            var state = {
                title: 'TapTap',
                url: '#'
            };

            window.history.pushState(state, "TapTap", '#');
            window.addEventListener('popstate', function popstate(e) {
                let newUri = new Tap.URI();
                if (newUri.get('utm_source') == 'baidu' || newUri.get('utm_medium') == 'sem') {
                    window.removeEventListener('popstate', popstate, false);
                    location.assign('/');
                }
            }, false);


        }
    })();
    </script>
            

</body>
<body>
</body>
</html>
'''

# %%
page_html = bs.BeautifulSoup(text) 
news_containers = page_html.find_all("div", class_= "taptap-app-list") 
titles = []
urls = []
gametypes = []
scores = []

for container in news_containers:
    for link in container.find_all("a", class_="item-caption-title flex-text-overflow taptap-link"): 
        titles.append(link.text.strip()) 
        urls.append(link.get("href")) 
        
    for gametype in container.find_all("span", class_="item-caption-label"):
        gametypes.append(gametype.a.string)
        
    for score in container.find_all("span", class_="caption-label-rating pull-right"):
        scores.append(score.span.string)
        
datatop1_0 = {
    "titles":titles,
    "urls":urls,
    "gametypes":gametypes,
    "scores":scores
}

import pandas as pd 
Top1_0_Tencent = pd.DataFrame.from_dict(datatop1_0, orient ="index").transpose()
Top1_0_Tencent.to_csv("Top1_0_Tencent.csv")

# %%
Top1_0_Tencent
# Out:
#                 titles                               urls gametypes scores
# 0                 雪鹰领主   https://www.taptap.com/app/85845      角色扮演    5.5
# 1             FIFA足球世界   https://www.taptap.com/app/72784        模拟    3.0
# 2             龙族幻想\nCN  https://www.taptap.com/app/139184      角色扮演    4.5
# 3           多多自走棋（体验服）  https://www.taptap.com/app/169944        策略    6.0
# 4                三国群英传   https://www.taptap.com/app/58944      角色扮演    5.0
# 5            QQ飞车（体验服）  https://www.taptap.com/app/130754        竞速    4.4
# 6                 全民小镇    https://www.taptap.com/app/6988        策略    6.8
# 7                最强NBA   https://www.taptap.com/app/57395        体育    4.8
# 8     我的英雄学院：最强英雄（测试服）  https://www.taptap.com/app/178479        动作    6.9
# 9                街霸：对决  https://www.taptap.com/app/139157      角色扮演    4.9
# 10               代号：息壤  https://www.taptap.com/app/178358      角色扮演    8.5
# ...

# %% [markdown]
# # Top 1_1 Tencent Games(腾讯游戏国际)

# %%
source = requests.get("https://www.taptap.com/developer/6771/apps") 
page_html = bs.BeautifulSoup(source.content, "html.parser") 
news_containers = page_html.find_all("div", class_= "taptap-app-list") 
titles = []
urls = []
gametypes = []
scores = []

for container in news_containers:
    for link in container.find_all("a", class_="item-caption-title flex-text-overflow taptap-link"): 
        titles.append(link.text.strip()) 
        urls.append(link.get("href")) 
        
    for gametype in container.find_all("span", class_="item-caption-label"):
        gametypes.append(gametype.a.string)
        
    for score in container.find_all("span", class_="caption-label-rating pull-right"):
        scores.append(score.span.string)
        
datatop1_1 = {
    "titles":titles,
    "urls":urls,
    "gametypes":gametypes,
    "scores":scores
}

import pandas as pd 
Top1_1_Tencent_Games = pd.DataFrame.from_dict(datatop1_1, orient ="index").transpose()
Top1_1_Tencent_Games.to_csv("Top1_1_Tencent_Games.csv")

# %%
Top1_1_Tencent_Games
# Out:
#                    titles                               urls gametypes scores
# 0        콜 오브 듀티: 모바일\nKR  https://www.taptap.com/app/171385        动作    9.0
# 1        PUBG MOBILE BETA  https://www.taptap.com/app/152741      角色扮演    7.0
# 2         PUBG MOBILE\nUS   https://www.taptap.com/app/83084        动作    8.3
# 3         PUBG Mobile\nKR   https://www.taptap.com/app/91962        动作    8.5
# 4          Chess Rush\nUS  https://www.taptap.com/app/170403      角色扮演    8.2
# 5          爆走Drifters\nJP  https://www.taptap.com/app/177479        竞速    9.3
# 6          Ludo Superstar  https://www.taptap.com/app/151427     桌面和棋类    8.4
# 7        PUBG MOBILE LITE  https://www.taptap.com/app/140539        动作    7.0
# 8   PUBG MOBILE：绝地求生M\nTW  https://www.taptap.com/app/162352      角色扮演    7.8
# 9   伝説対決 -Arena of Valor-  https://www.taptap.com/app/149718        动作    9.1
# 10         Land of Daimon   https://www.taptap.com/app/15210      角色扮演    1.3
# ...

# %% [markdown]
# # Top 1_2 A.C.E Program(极光计划)

# %%
text='''<body class="app-body
            
            pc
            
                                ">

                
                
                <nav class="navbar navbar-default" id="navbar">
    <div class="container">
        <div class="navbar-header">
            <button type="button" class="navbar-toggle collapsed" data-taptap-slide="nav" data-target="#navbarSlide" aria-expanded="false">
                <span class="sr-only">Toggle navigation</span>
                <span class="icon-bar"></span>
                <span class="icon-bar"></span>
                <span class="icon-bar"></span>
            </button>
            <a class="navbar-brand" href="https://www.taptap.com">
            </a>
            <a href="https://www.taptap.com/mobile" class="navbar-header-xz">
                                    <i class="taptap-icon icon-mobile-download"></i>
                            </a>
        </div>
        <div class="navbar-collapse" id="navbarSlide">
            <div class="narbar-collapse-btn">
                <button class="btn btn-default" data-taptap-slide="nav" data-target="#navbarSlide" type="button">
                    <i class="taptap-icon icon-arrow-left"></i>
                </button>
            </div>
            <ul class="nav navbar-nav navbar-left">
                <li>
                    <a href="https://www.taptap.com">首页</a>
                </li>
                <li>
                                            <a href="https://www.taptap.com/top/download">排行榜</a>
                                    </li>
                <li>
                    <a href="https://www.taptap.com/review/new">安利墙</a>
                </li>
                <li>
                    <a href="https://www.taptap.com/categories">发现</a>
                </li>
                <li>
                    <a href="https://www.taptap.com/forum/hot">论坛</a>
                </li>
                                                                                        <li>
                        <a href="https://www.taptap.com/video">视频</a>
                    </li>
                            </ul>
        </div>
        <div class="navbar-mask" data-taptap-slide="nav" data-target="#navbarSlide"></div>
        <ul class="nav navbar-nav navbar-right">
            <li>
                <button class="navbar-search btn btn-default js-emit" tap-event="search.show" data-taptap-nav="search" type="button">
                    <i class="icon-font icon-searchnew"></i>
                </button>
            </li>
            <li class="dropdown navbar-notice hide">
                <button id="taptap-notification" class="btn btn-default taptap-notice-bell" data-taptap-ajax="notification" data-message-total="条新消息" type="button" data-unread="0" data-get-unread-total-url="https://www.taptap.com/ajax/notification/un-read-total" data-url="https://www.taptap.com/ajax/notification" onclick="ga('send','event','Topbar','Notification','MenuExpand')">
    <i class=""></i>
</button>
                <div class="taptap-notice-widget" id="ajaxNotifications" style="display: none;">
    <div class="notice-widget-loading" data-taptap-ajax-notification="loading">
        <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="">
    </div>
</div>
            </li>
            <li class="dropdown navbar-user">
                <a href="https://www.taptap.com/auth/login" class="img-circle avatar-wrap" rel="nofollow" role="button" aria-haspopup="true" aria-expanded="false">
                    <img src="https://img.tapimg.com/market/images/22f1196f825298281376608459bfa7fe.png" alt="">
                </a>
                <input type="hidden" value="个人中心" id="dashboard">
                <input type="hidden" value="我的关注" id="my_following">
                <input type="hidden" value="我的收藏" id="my_collections">
                <input type="hidden" value="我的订单" id="my_orders">
                <input type="hidden" value="篝火计划" id="campfire">
                <input type="hidden" value="浏览历史" id="browse_history">
                <input type="hidden" value="我的草稿" id="draft_box">
                <input type="hidden" value="开发者中心" id="developer_center">
                <input type="hidden" value="登出" id="logout">
                <input type="hidden" value="解冻账号" id="activate">
            </li>
        </ul>
                <form class="navbar-form" id="search" role="search" method="get" action="https://www.taptap.com/search">
            <div class="form-group">
              <button type="submit" class="btn btn-default">
                <i class="icon-font icon-search2"></i>
              </button>
                <input type="text" class="form-control js-emit search-input" tap-event="click:search.show,change:search.apps,keydown:search.keydown" autocomplete="off" id="search-kw" name="kw" value="" placeholder="搜索...">
            </div>
                                        <div class="taptap-search ">
        <div class="supports">
        <section class="history">
            <header>
                历史搜索
                <span class="clear-history">
                    <button class="js-emit" tap-event="search.clear-history" type="button">清空</button>
                </span>
            </header>
            <div class="list">
                <ul class="list-unstyled">
                    <li class="loading">
                        <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading">
                    </li>
                </ul>
            </div>
        </section>
        <section class="hot-word">
            <header>热门搜索</header>
            <div class="list">
                <ul class="list-unstyled">
                </ul>
            </div>
        </section>
        <section class="results show">
      <div class="loading">
      <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading">
    </div>
  </section>
    </div>
</div>
                    </form>
    </div>
</nav>
                        <section class="taptap-breadcrumb">
            <div class="container">
                <div class="row">
                    <ol class="breadcrumb">
                        <li><span>你的位置:</span></li>
                        <li><a href="https://www.taptap.com">首页</a></li>
                        
    <li><a href="https://www.taptap.com/developer/28666">极光计划</a></li>
    <li class="active"><span>厂商游戏</span></li>

                    </ol>
                    <span class="breadcrumb-end"></span>
                </div>
            </div>
        </section>
        
            <div class="container">
        <div class="row">
            <div class="col-sm-12">
                <section class="app-category-list">
                    <div class="section-title">
                        <h1>厂商游戏</h1>
                    </div>
                    <div class="tab-content">
                        <div class="tab-pane active" role="tab" id="apps">
                            <div class="taptap-app-list" id="appList">
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/135968" data-taptap-url="taptap://taptap.com/app?app_id=135968&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/33fd9480cf54eb5c6e59ba9e50ca917d_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/33fd9480cf54eb5c6e59ba9e50ca917d_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="银河掠夺者" title="银河掠夺者" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/135968" data-taptap-url="taptap://taptap.com/app?app_id=135968&amp;style=0" title="银河掠夺者">
            <h4 class="flex-text">银河掠夺者</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/rpg" data-taptap-url="taptap://taptap.com/app_tag?tag=角色扮演" class="taptap-link">角色扮演</a>
                        <span class="caption-label-rating pull-right">
                <span>6.5</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/91227" data-taptap-url="taptap://taptap.com/app?app_id=91227&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/f886be77c83ddff5e47680d1bfef8de2_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/f886be77c83ddff5e47680d1bfef8de2_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="砖块迷宫建造者" title="砖块迷宫建造者" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/91227" data-taptap-url="taptap://taptap.com/app?app_id=91227&amp;style=0" title="砖块迷宫建造者">
            <h4 class="flex-text">砖块迷宫建造者</h4>
                            <small class="taptap-app-area">CN</small>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/strategy" data-taptap-url="taptap://taptap.com/app_tag?tag=策略" class="taptap-link">策略</a>
                        <span class="caption-label-rating pull-right">
                <span>10</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/79031" data-taptap-url="taptap://taptap.com/app?app_id=79031&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/icons/e9220ea6362a8444f04449bb573fa36f_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/icons/e9220ea6362a8444f04449bb573fa36f_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="带你回家" title="带你回家" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/79031" data-taptap-url="taptap://taptap.com/app?app_id=79031&amp;style=0" title="带你回家">
            <h4 class="flex-text">带你回家</h4>
                            <small class="taptap-app-area">CN</small>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/puzzle" data-taptap-url="taptap://taptap.com/app_tag?tag=知识问答" class="taptap-link">知识问答</a>
                        <span class="caption-label-rating pull-right">
                <span>9.0</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app
360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="全城封锁末日求生" title="全城封锁末日求生" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/83248" data-taptap-url="taptap://taptap.com/app?app_id=83248&amp;style=0" title="全城封锁末日求生">
            <h4 class="flex-text">全城封锁末日求生</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/adventure" data-taptap-url="taptap://taptap.com/app_tag?tag=冒险" class="taptap-link">冒险</a>
                        <span class="caption-label-rating pull-right">
                <span>4.5</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
<div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/15444" data-taptap-url="taptap://taptap.com/app?app_id=15444&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/cc44d9c664220901f1270e537b7e6269_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/cc44d9c664220901f1270e537b7e6269_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="众生游" title="众生游" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/15444" data-taptap-url="taptap://taptap.com/app?app_id=15444&amp;style=0" title="众生游">
            <h4 class="flex-text">众生游</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/simulation" data-taptap-url="taptap://taptap.com/app_tag?tag=模拟" class="taptap-link">模拟</a>
                        <span class="caption-label-rating pull-right">
                <span>9.5</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
<div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/22455" data-taptap-url="taptap://taptap.com/app?app_id=22455&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/d37d2d521b5dffc0616c252f3db99914_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/d37d2d521b5dffc0616c252f3db99914_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="贪吃小怪物" title="贪吃小怪物" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/22455" data-taptap-url="taptap://taptap.com/app?app_id=22455&amp;style=0" title="贪吃小怪物">
            <h4 class="flex-text">贪吃小怪物</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/casual" data-taptap-url="taptap://taptap.com/app_tag?tag=休闲" class="taptap-link">休闲</a>
                        <span class="caption-label-rating pull-right">
                <span>7.0</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
<div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/52276" data-taptap-url="taptap://taptap.com/app?app_id=52276&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/9fcc8416b506b98393ed373d919da5b4_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/9fcc8416b506b98393ed373d919da5b4_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="纪念碑谷2" title="纪念碑谷2" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/52276" data-taptap-url="taptap://taptap.com/app?app_id=52276&amp;style=0" title="纪念碑谷2">
            <h4 class="flex-text">纪念碑谷2</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/adventure" data-taptap-url="taptap://taptap.com/app_tag?tag=冒险" class="taptap-link">冒险</a>
                        <span class="caption-label-rating pull-right">
                <span>9.1</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
<div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/64075" data-taptap-url="taptap://taptap.com/app?app_id=64075&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/e3ae072702129e3017a915d3d5786189_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/e3ae072702129e3017a915d3d5786189_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="猫咪别追我" title="猫咪别追我" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/64075" data-taptap-url="taptap://taptap.com/app?app_id=64075&amp;style=0" title="猫咪别追我">
            <h4 class="flex-text">猫咪别追我</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/casual" data-taptap-url="taptap://taptap.com/app_tag?tag=休闲" class="taptap-link">休闲</a>
                        <span class="caption-label-rating pull-right">
                <span>9.1</span>
                <i></i>
            </span>
                    </span>
            </div>
</div></div>
                                                            <section class="taptap-button-more load-more">
    <button class="btn btn-primary btn-lg" data-taptap-ajax="more" data-method="get" data-target="#appList" data-url="https://www.taptap.com/ajax/developer/apps/28666?page=2" type="button" style="display: none;">更多</button>
    <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="" data-taptap-ajax-more="loading" style="display: none;">
</section>
                                                    </div>
                    </div>
                </section>
            </div>
        </div>
    </div>

                            <footer class="footer">
    <div class="container">
        <div class="row">
            <div class="col-sm-12 clearfix">
                <div class="pull-right">
                    <p>Contact Us</p>
                    <ul class="list-inline">
                        <li>
                            <a class="icon-font ic_facebook" href="https://www.facebook.com/gametaptap/" target="_blank" title="Facebook" rel="nofollow"></a>
                        </li>
                        <li>
                            <span class="icon-font ic_wechat" title="微信"></span>
                            <div>
                                <span class="thumbnail">
                                    <img src="https://img.tapimg.com/market/images/c4bf2701e3ee9993e1ee0b8222480a35.jpg" alt="">
                                </span>
                            </div>
                        </li>
                        <li>
                            <span class="icon-font ic_qq" title="QQ"></span>
                            <div>
                                <span class="thumbnail">官方QQ群: 780255342</span>
                            </div>
                        </li>
                        <li>
                            <a class="icon-font ic_zhihu" href="https://zhuanlan.zhihu.com/taptap" target="_blank" title="知乎" rel="nofollow"></a>
                        </li>
                        <li>
                            <a class="icon-font ic_sina" href="http://weibo.com/taptapgames" target="_blank" title="微博" rel="nofollow"></a>
                        </li>
                        <li>
                            <span class="icon-font ic_mail" title="邮箱"></span>
                            <div>
                                <span class="thumbnail">
                                    合作邮箱: <a href="mailto:cooperation@taptap.com" rel="nofollow">cooperation@taptap.com</a>
                                </span>
                            </div>
                        </li>
                    </ul>
                                                                        <p>官方活动</p>
                                            <div class="events-link">
                        <span class="link">
                            <a href="https://www.taptap.com/events/3rd-anniversary" rel="nofollow" onclick="ga('send','event','bottom-entry','click','thirdAnniversary');sa.click({position: '页脚'}, event)">TapTap 三周年</a>
                        </span>
                        <span class="link">
                            <a href="https://www.taptap.com/campfire" rel="nofollow" onclick="ga('send','event','bottom-entry','click','campfire');sa.click({position: '页脚'}, event)">篝火计划</a>
                        </span>
                        <span class="link">
                            <a href="https://www.taptap.com/events/3rd-anniversary/doodle" rel="nofollow" onclick="ga('send','event','bottom-entry','click','doodle2019');sa.click({position: '页脚'}, event)">涂鸦大赛</a>
                        </span>
                        <span class="link">
                            <a href="https://www.taptap.com/game-awards2018" rel="nofollow" onclick="ga('send','event','bottom-entry','click','gameAwards2018');sa.click({position: '页脚'}, event)">2018年度游戏大赏</a>
                        </span>
                    </div>
                                                        </div>
                <div class="footer-left">
                    <div class="footer-left-header">
                        <span class="left-header-logo">
                            <img src="https://assets.tapimg.com/img/ic_logocn@3x.png?20190610" alt="TapTap 中国" title="TapTap 中国">
                        </span>
                        <div class="dropdown">
                                                                                                                <button id="regionSelect" type="button" class="btn btn-link" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                                中文 (简体)
                                <span class="caret"></span>
                            </button>
                            <ul class="dropdown-menu" aria-labelledby="regionSelect">
                                <li><span class="dropdown-tips">选择语言</span></li>
                                                                    <li class="active">
                                            <a href="https://www.taptap.com/set-region?region=cn" class="js-http-post" rel="nofollow">中文 (简体)</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=tw" class="js-http-post" rel="nofollow">中文 (繁體)</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=us" class="js-http-post" rel="nofollow">English</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=jp" class="js-http-post" rel="nofollow">日本語</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=kr" class="js-http-post" rel="nofollow">한국어</a>
                                    </li>
                                                            </ul>
                        </div>
                        <p class="links">
                            <span class="link">
                                <a href="https://www.taptap.com/developer" rel="nofollow">开发者中心</a>
                            </span>
                                                            <span class="link">
                                    <a href="https://www.taptap.com/developer/developer-distribution-agreement" rel="nofollow">开发者协议</a>
                                </span>
                                                        <span class="link">
                                <a href="https://www.taptap.com/ads" rel="nofollow">广告投放</a>
                            </span>
                            <span class="link">
                                <a href="https://www.taptap.com/about-us" rel="nofollow">关于我们</a>
                            </span>
                            <span class="link">
                                <a href="https://www.taptap.com/hr" rel="nofollow">加入我们</a>
                            </span>
                                                        <span class="link">
                                <a href="https://www.taptap.com/user-verification" rel="nofollow">用户认证</a>
                            </span>
                                                    </p>
                    </div>
                    <p>Discover Superb Games.</p>
                    <span>
                        <span>Copyright © 2019 <a href="https://www.taptap.com">TapTap</a>. All rights Reserved.</span>
                        <br>
                        <span>适龄提示: 本公司产品适合 10 周岁以上玩家使用</span>
                        <span>&nbsp;<a href="https://www.taptap.com/taptapjh" target="_blank" rel="nofollow">未成年人家长监护</a>&nbsp;&nbsp;                            <a href="https://www.taptap.com/privacy-policy" rel="nofollow">隐私政策</a>&nbsp;&nbsp;
                            <a href="https://www.taptap.com/copyright" rel="nofollow">侵权投诉</a>                         </span>
                        <br>
                                                <span>
                            <a href="http://www.beian.miit.gov.cn/" target="_blank" rel="nofollow">沪ICP备16012525号-1</a>&nbsp;&nbsp;
                            <a href="/license/www.html">沪网文(2019)3544-255号&nbsp;&nbsp;</a>
                        </span>
                        <br>
                                                <span class="manage">经营许可证编号: 沪B2-20170322</span>易玩（上海）网络科技有限公司
                        <br>
                        <span>公司地址: 上海市静安区万荣路 700 号 A3 202</span>
                    </span>
                </div>
            </div>
                            <div class="col-sm-12 clearfix">
                    <span class="record-filing">
                        <a target="_blank" href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=31010402003255" rel="nofollow">
                            <img src="https://img.tapimg.com/market/images/d0289dc0a46fc5b15b3363ffa78cf6c7.png">
                            <p>沪公网安备 31010402003255号</p>
                        </a>
                        <a target="_blank" href="http://sq.ccm.gov.cn:80/ccnt/sczr/service/business/emark/toDetail/35EE6340BAC97151E0530140A8C0E25A" rel="nofollow">
                            <img src="https://img.tapimg.com/market/images/d839a60d8749eca93b9ca669583e65f4.png">
                            <p>互联网文化经营单位</p>
                        </a>
                        <a target="_blank" href="http://www.shjbzx.cn/" class="report" title="上海市互联网违法和不良信息举报中心" rel="nofollow">
                            <img src="https://img.tapimg.com/market/images/205fb1dc7c6c602e57c1b8e6477529d4.png">
                        </a>
                                            </span>
                </div>
                    </div>
    </div>
</footer>
        
        
                                    <section class="modal fade taptap-modal global-tip-modal" tabindex="-1" role="dialog" id="global-tip-modal">
    <div class="modal-dialog">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
                <h4 class="modal-title" data-default-text="提示">提示</h4>
            </div>
            <div class="modal-body">
                <p></p>
            </div>
            <div class="modal-footer">
                <button class="btn btn-primary" data-default-text="确定">确定</button>
                <button class="btn btn-default" data-dismiss="modal" data-default-text="取消">取消</button>
            </div>
        </div>
    </div>
</section>
    <div class="modal fade taptap-modal taptap-alert taptap-alert-success" tabindex="-1" role="dialog" id="operation-state-modal">
  <div class="modal-dialog">
    <div class="modal-content">
      <div class="modal-body">
        <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
        <div class="alert-logo success">
          <span></span>
        </div>
        <p class="alert-message-title"></p>
        <p class="alert-message single-line">成功</p>
        <div class="html-render"></div>
              </div>
    </div>
  </div>
</div>
    <div class="taptap-simple-alert" id="simpleAlertModal">
  <button type="button"><span aria-hidden="true">×</span></button>
  <span class="alert-logo fail">
    <i class="icon-font icon-error"></i>
    <p class="alert-message">trans('interface.word.success')</p>
  </span>
</div>
    <section class="taptap-button-top" data-taptap-widgets="container" data-taptap-go="top" style="display: block;">
    <i class="icon-font icon-stick"></i>
</section>
                <section class="taptap-bottom-banner collapse" id="bottomBanner">
    <div class="container">
        <div class="row">
            <div class="col-sm-12 clearfix">
                <div class="bottom-banner-left">
                    <img src="https://img.tapimg.com/market/images/dcaacad6231ac7003cf1b62b6643c450.png" alt="">
                </div>
                <div class="bottom-banner-center">
                    <ul class="list-unstyled">
                                                <li>
                            <span></span>
                            <p>一天一款全球精品游戏推荐，活跃的玩家交流社区</p>
                        </li>
                                                <li>
                            <span></span>
                            <p>只收录官方包，不联运，支持安卓正版游戏购买</p>
                        </li>
                                                <li>
                            <span></span>
                            <p> 倡导真实评分评价，排行榜单来自玩家真实反馈</p>
                        </li>
                                            </ul>
                    <p>
                        <span>TapTap</span>
                        <br>
                        发现好游戏
                    </p>
                </div>
                <div class="bottom-banner-right">
                    <button class="close" type="button" data-toggle="collapse" data-target="#bottomBanner" data-taptap-cookie-set="bottom_banner_hidden" data-days="365" data-value="1">
                        <i class="taptap-icon icon-times"></i>
                    </button>
                    <div class="banner-right-btns">
                        <button class="btn btn-default taptap-button-hollow" data-taptap-modal="qrcode">
                            二维码下载
                            <span data-taptap-qrcode="generate" data-url="https://d.taptap.com/latest"><canvas width="100" height="100"></canvas></span>
                        </button>
                        <a href="https://d.taptap.com/latest" class="btn btn-success" onclick="ga('send', 'event', 'Client', 'BottombarDownload');sa.perform({action: 'Download', type: 'BottomBanner'});" rel="nofollow">
                            <span class="desktop">免费下载</span>
                            <span class="mobile">下载</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div>
</section>
                    <section class="modal fade taptap-modal login-tips" tabindex="-1" role="dialog" aria-labelledby="loginTipsModal" id="loginTipsModal">
    <div class="modal-dialog">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
                <h4 class="modal-title">温馨提示</h4>
            </div>
            <div class="modal-body">
                <p>请先<a href="/auth/login" rel="nofollow">登录</a>后，再进行操作</p>
            </div>
        </div>
    </div>
</section>                <section class="modal fade taptap-modal login-form" tabindex="-1" role="dialog" aria-labelledby="loginFormModal" id="loginFormModal">
    <div class="modal-dialog">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
                <h4 class="modal-title"></h4>
            </div>
            <div class="modal-body auth-main">
                <div class="auth-main-body login">

                </div>

            </div>
        </div>
    </div>
</section>
        <section class="modal fade taptap-modal phone-captcha-modal" tabindex="-1" role="dialog" aria-labelledby="phoneCaptcha" id="phoneCaptcha">
    <div class="modal-dialog ">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div class="modal-content">
                <h5>请输入短信验证码</h5>
                                    <div id="phone-captcha" class="phone-captcha">
                        <input type="text" maxlength="1" autofocus="" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                    </div>
                                <div class="loading"><img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading"></div>
                <div class="error"></div>
            </div>
            <div class="modal-footer">
                <div class="code-tip" data-taptap-has-send="true">
                    <p>短信验证码已发送至<span id="phone-number">+86xxxxxxxxxxxx</span></p>
                    <p><span id="count" class="count">59</span>&nbsp;秒后可重新发送</p>
                </div>
                <div class="code-tip" data-taptap-has-send="false">
                    <p class="send-again-container">
                        <span class="send-loading"><img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading"></span>
                        <span id="send-again" class="count" tap-event="sendPhoneCaptcha">重新发送</span>
                    </p>
                </div>
            </div>
        </div>
    </div>
</section>
            
            <div class="modal fade taptap-modal user-certification" tabindex="-1" role="dialog" id="verifyIdcardModal">
  <div class="modal-dialog">
    <div class="modal-content">
      <form action="" method="post" id="verifyIdcardForm">
        <input type="hidden" name="_token" value="AVT9QB4LcFIvuCyAUSfFxtA1Ad77K2wFcaaAwGav">
        <div class="modal-header">
          <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
          <h4 class="modal-title">实名信息提交</h4>
        </div>
        <div class="modal-body">
          <div class="common-form-fields">
            <div class="common-form-basic-title">
              <h3><span>真实姓名</span></h3>
            </div>
            <p class="common-field">
              <input type="text" name="real_name" class="common-form-text" id="real-name">
            </p>
            <div class="common-form-basic-title">
              <h3><span>身份证号码</span></h3>
            </div>
            <p class="common-field">
              <input type="text" name="idcard" class="common-form-text" id="idcard-number">
            </p>
          </div>
          <p class="note">*请使用真实姓名及有效身份证号码进行实名信息提交<br>*身份信息提交后不可进行修改<br>*有意填写非本人身份信息者，被发现将对账号进行封禁处理<br>*如有疑问，可联系 TapTap 客服邮箱：kefu@taptap.com</p>
        </div>
        <div class="modal-footer">
          <button type="submit" class="btn btn-primary" data-url="https://www.taptap.com/ajax/profile/idcard" id="verify-submit">提交</button>
                  </div>
      </form>
    </div>
  </div>
</div>
                <script>
    (function (i, s, o, g, r, a, m) {
        i['GoogleAnalyticsObject'] = r;
        i[r] = i[r] || function () {
            (i[r].q = i[r].q || []).push(arguments)
        }, i[r].l = 1 * new Date();
        a = s.createElement(o),
            m = s.getElementsByTagName(o)[0];
        a.async = 1;
        a.src = g;
        m.parentNode.insertBefore(a, m)
    })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');

            ga('create', 'UA-73963350-1', 'auto');
    
    var browserName = "Other";
    var ua = window.navigator.userAgent;
    browserRegExp = {
        iOSSDK: /TapTapiOSSDK/,
        AndroidSDK: /TapTapAndroidSDK/,
        Sogou: /SE\s2\.X|SogouMobileBrowser/,
        Explorer2345: /2345Explorer|2345chrome|Mb2345Browser/,
        Liebao: /LBBROWSER/,
        Wechat: /MicroMessenger/,
        QQBrowser: /QQBrowser/,
        Baidu: /BIDUBrowser|baidubrowser|BaiduHD/,
        UC: /UBrowser|UCBrowser|UCWEB/,
        MiuiBrowser: /MiuiBrowser/,
        MobileQQ: /Mobile\/\w{5,}\sQQ\/(\d+[\.\d]+)/,
        Shoujibaidu: /baiduboxapp/,
        SamsungBrowser: /samsungbrowser/,
        Firefox: /Firefox/,
        Maxthon: /Maxthon/,
        Se360: /360SE/,
        Ee360: /360EE/,
        TheWorld: /TheWorld/,
        Weibo: /__weibo__/,
        NokiaBrowser: /NokiaBrowser/,
        Opera: /Opera|OPR\/(\d+[\.\d]+)/,
        Edge: /Edge/,
        QQLive: /QQLive(HD)?Browser/,
        Letv: /LetvClient/,
        Youku: /Youku/,
        AndroidBrowser: /Android.*Mobile\sSafari|Android\/(\d[\.\d]+)\sRelease\/(\d[\.\d]+)\sBrowser\/AppleWebKit(\d[\.\d]+)/i,
        IE: /Trident|MSIE/,
        TouTiao: /NewsArticle/,
        Chrome: /Chrome|CriOS/,
        Safari: /Version[|\/]([\w.]+)(\s\w.+)?\s?Safari|like\sGecko\)\sMobile\/\w{3,}$/,
    };

    if (window.tapEnv && window.tapEnv.browser && window.tapEnv.browser.inApp === true) {
        browserName = "InApp";
    } else {
        for (var i in browserRegExp) {
            if (browserRegExp[i].exec(ua)) {
                browserName = i;
                break;
            }
        }
    }

    if(window.tapEnv && window.tapEnv.user && window.tapEnv.user.id) {
        ga('set', 'dimension4', 'login');
    } else {
        ga('set', 'dimension4', 'guest');
    }

    if (browserName === "Other") {
        ga('set', 'dimension2', browserName + "-" + ua);
    } else {
        ga('set', 'dimension1', browserName);
    }

    ga('send', 'pageview');
</script>

<script>
(function (para) {
  var p = para.sdk_url, n = para.name, w = window, d = document, s = 'script', x = null, y = null;
  w['sensorsDataAnalytic201505'] = n;
  w[n] = w[n] || function (a) {
    return function () {
      (w[n]._q = w[n]._q || []).push([a, arguments]);
    }
  };
  var ifs = ['track', 'quick', 'register', 'registerPage', 'registerOnce', 'trackSignup', 'trackAbtest', 'setProfile', 'setOnceProfile', 'appendProfile', 'incrementProfile', 'deleteProfile', 'unsetProfile', 'identify', 'login', 'logout', 'trackLink', 'clearAllRegister', 'getAppStatus'];
  for (var i = 0; i < ifs.length; i++) {
    w[n][ifs[i]] = w[n].call(null, ifs[i]);
  }
  if (!w[n]._t) {
    x = d.createElement(s), y = d.getElementsByTagName(s)[0];
    x.async = 1;
    x.src = p;
    x.setAttribute('charset', 'UTF-8');
    y.parentNode.insertBefore(x, y);
    w[n].para = para;
  }
})({
  sdk_url: 'https://assets.tapimg.com/scripts/sensorsdata.min.js',
  heatmap_url: 'https://assets.tapimg.com/scripts/heatmap.min.js',
  name: 'sensorsSDK',
  web_url: 'https://sa.taptap.com/',
  server_url: 'https://sd.taptap.com/sa',
  show_log: false
});
window.sa = {
  post: function (props) {
    sensorsSDK.track('WebPost', props);
  },
  perform: function (props) {
    sensorsSDK.track('WebPerform', props);
  },
  click: function (props, event) {
    var target = event.target ? event.target : event.srcElement;
    target = target.closest('a');
    props.target_url = target.href;
    props.target_path = target.pathname
    sensorsSDK.track('$WebClick', props);
  },
  login: function (props) {
    sensorsSDK.track('WebLogin', props);
  }
};
(function () {
  var registerProps = {
    url: Tap.URI(location.href).pure().toString(),
    referer: document.referrer,
    path: location.pathname
  }
  if (Tap.browser.is('inApp')) {
    registerProps['client'] = Tap.env('browser.inAppPn', 'Unknown');
  }
  sensorsSDK.registerPage(registerProps);

  var user_id = $('meta[name=user_id]').attr('content');
  if (user_id) {
    sensorsSDK.login(user_id)
  } else {
    sensorsSDK.logout();
  }
  sensorsSDK.quick('autoTrack');
})();
</script>


<script>
        (function () {
        var tapUri = new Tap.URI();

        var bp = document.createElement('script');
        var curProtocol = window.location.protocol.split(':')[0];
        if (curProtocol === 'https') {
            bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
        }
        else {
            bp.src = 'http://push.zhanzhang.baidu.com/push.js';
        }
        var s = document.getElementsByTagName("script")[0];
        s.parentNode.insertBefore(bp, s);

                        var referrer = document.referrer;
        var bdUri;
        var bdsem;
        if (referrer) {
            bdUri = new Tap.URI(referrer);
            bdsem = bdUri.parse();
        }

        if ((tapUri.get('utm_source') == 'baidu' || tapUri.get('utm_medium') == 'sem' || (bdsem !== undefined && bdsem['path'] == 'baidu.php'))
            && Tap.browser.is('mobile')) {

            var state = {
                title: 'TapTap',
                url: '#'
            };

            window.history.pushState(state, "TapTap", '#');
            window.addEventListener('popstate', function popstate(e) {
                let newUri = new Tap.URI();
                if (newUri.get('utm_source') == 'baidu' || newUri.get('utm_medium') == 'sem') {
                    window.removeEventListener('popstate', popstate, false);
                    location.assign('/');
                }
            }, false);


        }
    })();
    </script>
            

</body>'''

# %%
page_html = bs.BeautifulSoup(text) 
news_containers = page_html.find_all("div", class_= "taptap-app-list") 
titles = []
urls = []
gametypes = []
scores = []

for container in news_containers:
    for link in container.find_all("a", class_="item-caption-title flex-text-overflow taptap-link"): 
        titles.append(link.text.strip()) 
        urls.append(link.get("href")) 
        
    for gametype in container.find_all("span", class_="item-caption-label"):
        gametypes.append(gametype.a.string)
        
    for score in container.find_all("span", class_="caption-label-rating pull-right"):
        scores.append(score.span.string)
        
datatop1_2 = {
    "titles":titles,
    "urls":urls,
    "gametypes":gametypes,
    "scores":scores
}

import pandas as pd 
Top1_2_ACE_Program = pd.DataFrame.from_dict(datatop1_2, orient ="index").transpose()
Top1_2_ACE_Program.to_csv("Top1_2_ACE_Programt.csv")

# %%
Top1_2_ACE_Program
# Out:
#            titles                               urls gametypes scores
# 0           银河掠夺者  https://www.taptap.com/app/135968      角色扮演    6.5
# 1     砖块迷宫建造者\nCN   https://www.taptap.com/app/91227        策略     10
# 2        带你回家\nCN   https://www.taptap.com/app/79031      知识问答    9.0
# 3         维恩的最后零件  https://www.taptap.com/app/164949        冒险    6.7
# 4               洼   https://www.taptap.com/app/80041        音乐    9.4
# 5        执剑之刻\nCN   https://www.taptap.com/app/60465      角色扮演    6.7
# 6            闹闹天宫   https://www.taptap.com/app/73985        动作    7.3
# 7              牌师   https://www.taptap.com/app/67170        卡牌    8.0
# 8            我的侠客  https://www.taptap.com/app/172652      角色扮演    9.5
# 9            神明在上  https://www.taptap.com/app/159287      角色扮演    9.2
# 10      奇喵的画家\nCN  https://www.taptap.com/app/178034        休闲    9.9
# 11       海盗法则\nCN   https://www.taptap.com/app/72472        动作    6.0
# ...

# %% [markdown]
# # Top 1_3 Tencent Games Dreaming Plan(腾讯游戏追梦计划)

# %%
source = requests.get("https://www.taptap.com/developer/72999/apps") 
page_html = bs.BeautifulSoup(source.content, "html.parser") 
news_containers = page_html.find_all("div", class_= "taptap-app-list") 
titles = []
urls = []
gametypes = []
scores = []

for container in news_containers:
    for link in container.find_all("a", class_="item-caption-title flex-text-overflow taptap-link"): 
        titles.append(link.text.strip()) 
        urls.append(link.get("href")) 
        
    for gametype in container.find_all("span", class_="item-caption-label"):
        gametypes.append(gametype.a.string)
        
    for score in container.find_all("span", class_="caption-label-rating pull-right"):
        scores.append(score.span.string)
        
datatop1_3 = {
    "titles":titles,
    "urls":urls,
    "gametypes":gametypes,
    "scores":scores
}

import pandas as pd 
Top1_3_Tencent_Games_Dreaming_Plan = pd.DataFrame.from_dict(datatop1_3, orient ="index").transpose()
Top1_3_Tencent_Games_Dreaming_Plan.to_csv("Top1_3_Tencent_Games_Dreaming_Plan.csv")

# %%
Top1_3_Tencent_Games_Dreaming_Plan
# Out:
#           titles                               urls gametypes scores
# 0          普通话小镇  https://www.taptap.com/app/175750        益智    9.6
# 1            家国梦  https://www.taptap.com/app/172714        策略    8.8
# 2     佳期：重九（测试版）  https://www.taptap.com/app/155172        益智    8.8
# 3   电是怎么形成的（测试版）  https://www.taptap.com/app/139188        模拟    8.7
# 4   肿瘤医生中文版（测试版）   https://www.taptap.com/app/22419        模拟    8.8
# 5         见（测试版）  https://www.taptap.com/app/162251      角色扮演    9.8
# 6      长空暗影（测试版）  https://www.taptap.com/app/162252      角色扮演    8.6
# 7    纳木（测试版）\nCN  https://www.taptap.com/app/139189        益智    8.9
# 8           子曰诗云  https://www.taptap.com/app/139190        益智    9.6
# 9         折扇\nCN   https://www.taptap.com/app/81348        教育    8.9
# 10          榫接卯和   https://www.taptap.com/app/81347        教育    8.5

# %% [markdown]
# # Top 1_4 NEXT Studios(NEXT工作室)

# %%
source = requests.get("https://www.taptap.com/developer/27344/apps") 
page_html = bs.BeautifulSoup(source.content, "html.parser") 
news_containers = page_html.find_all("div", class_= "taptap-app-list") 
titles = []
urls = []
gametypes = []
scores = []

for container in news_containers:
    for link in container.find_all("a", class_="item-caption-title flex-text-overflow taptap-link"): 
        titles.append(link.text.strip()) 
        urls.append(link.get("href")) 
        
    for gametype in container.find_all("span", class_="item-caption-label"):
        gametypes.append(gametype.a.string)
        
    for score in container.find_all("span", class_="caption-label-rating pull-right"):
        scores.append(score.span.string)
        
datatop1_4 = {
    "titles":titles,
    "urls":urls,
    "gametypes":gametypes,
    "scores":scores
}

import pandas as pd 
Top1_4_NEXT_Studios = pd.DataFrame.from_dict(datatop1_4, orient ="index").transpose()
Top1_4_NEXT_Studios.to_csv("Top1_4_NEXT_Studios.csv")

# %%
Top1_4_NEXT_Studios
# Out:
#               titles                               urls gametypes scores
# 0          螺旋风暴（测试服）  https://www.taptap.com/app/151065        卡牌    7.2
# 1               螺旋风暴  https://www.taptap.com/app/149156        卡牌    8.7
# 2          金属对决（测试服）  https://www.taptap.com/app/175588        动作    7.6
# 3               金属对决  https://www.taptap.com/app/154843        动作    9.3
# 4               幽林怪谈  https://www.taptap.com/app/153741      角色扮演    9.0
# 5           欧呜欧（测试版）  https://www.taptap.com/app/138951        动作    8.9
# 6               疑案追声  https://www.taptap.com/app/154068        冒险    9.7
# 7   Death Coming\nTW  https://www.taptap.com/app/130175        策略    9.4
# 8               尼山萨满  https://www.taptap.com/app/135063        音乐    9.6
# 9               彩虹坠入  https://www.taptap.com/app/152332        休闲    9.5
# 10          死神來了\nCN   https://www.taptap.com/app/67617      角色扮演    9.3
# 11               三竹里   https://www.taptap.com/app/64945        益智    8.8

# %% [markdown]
# # Top 1_5 Tencent Institute of Games(腾讯NEXT IDEA高校游戏创意制作大赛)

# %%
source = requests.get("https://www.taptap.com/developer/78031/apps") 
page_html = bs.BeautifulSoup(source.content, "html.parser") 
news_containers = page_html.find_all("div", class_= "taptap-app-list") 
titles = []
urls = []
gametypes = []
scores = []

for container in news_containers:
    for link in container.find_all("a", class_="item-caption-title flex-text-overflow taptap-link"): 
        titles.append(link.text.strip()) 
        urls.append(link.get("href")) 
        
    for gametype in container.find_all("span", class_="item-caption-label"):
        gametypes.append(gametype.a.string)
        
    for score in container.find_all("span", class_="caption-label-rating pull-right"):
        scores.append(score.span.string)
        
datatop1_5 = {
    "titles":titles,
    "urls":urls,
    "gametypes":gametypes,
    "scores":scores
}

import pandas as pd 
Top1_5_Tencent_Institute_of_Games = pd.DataFrame.from_dict(datatop1_5, orient ="index").transpose()
Top1_5_Tencent_Institute_of_Games.to_csv("Top1_5_Tencent_Institute_of_Games.csv")

# %%
Top1_5_Tencent_Institute_of_Games
# Out:
#            titles                               urls gametypes scores
# 0            深暗森林  https://www.taptap.com/app/176794        策略    9.7
# 1              梦蝶  https://www.taptap.com/app/176805        休闲     10
# 2              良渚  https://www.taptap.com/app/176804      角色扮演     10
# 3        Retrieve  https://www.taptap.com/app/176803      角色扮演    9.6
# 4              斧曰  https://www.taptap.com/app/176802        休闲    9.7
# 5             桃都山  https://www.taptap.com/app/176800      角色扮演    9.2
# 6            物理世界  https://www.taptap.com/app/176797        休闲     10
# 7            铁山奇谭  https://www.taptap.com/app/176793      角色扮演    9.7
# 8              祖古  https://www.taptap.com/app/176791      角色扮演     10
# 9            未来双生  https://www.taptap.com/app/176790      角色扮演    7.4
# 10       Dr.POLPO  https://www.taptap.com/app/176789      角色扮演    7.8
# 11  Me and Myself  https://www.taptap.com/app/176787      角色扮演    9.9
# ...

# %% [markdown]
# # Top 2 NetEase Games(网易游戏)

# %%
text2='''<body class="app-body
            
            pc
            
                                ">

                
                
                <nav class="navbar navbar-default" id="navbar">
    <div class="container">
        <div class="navbar-header">
            <button type="button" class="navbar-toggle collapsed" data-taptap-slide="nav" data-target="#navbarSlide" aria-expanded="false">
                <span class="sr-only">Toggle navigation</span>
                <span class="icon-bar"></span>
                <span class="icon-bar"></span>
                <span class="icon-bar"></span>
            </button>
            <a class="navbar-brand" href="https://www.taptap.com">
            </a>
            <a href="https://www.taptap.com/mobile" class="navbar-header-xz">
                                    <i class="taptap-icon icon-mobile-download"></i>
                            </a>
        </div>
        <div class="navbar-collapse" id="navbarSlide">
            <div class="narbar-collapse-btn">
                <button class="btn btn-default" data-taptap-slide="nav" data-target="#navbarSlide" type="button">
                    <i class="taptap-icon icon-arrow-left"></i>
                </button>
            </div>
            <ul class="nav navbar-nav navbar-left">
                <li>
                    <a href="https://www.taptap.com">首页</a>
                </li>
                <li>
                                            <a href="https://www.taptap.com/top/download">排行榜</a>
                                    </li>
                <li>
                    <a href="https://www.taptap.com/review/new">安利墙</a>
                </li>
                <li>
                    <a href="https://www.taptap.com/categories">发现</a>
                </li>
                <li>
                    <a href="https://www.taptap.com/forum/hot">论坛</a>
                </li>
                                                                                        <li>
                        <a href="https://www.taptap.com/video">视频</a>
                    </li>
                            </ul>
        </div>
        <div class="navbar-mask" data-taptap-slide="nav" data-target="#navbarSlide"></div>
        <ul class="nav navbar-nav navbar-right">
            <li>
                <button class="navbar-search btn btn-default js-emit" tap-event="search.show" data-taptap-nav="search" type="button">
                    <i class="icon-font icon-searchnew"></i>
                </button>
            </li>
            <li class="dropdown navbar-notice hide">
                <button id="taptap-notification" class="btn btn-default taptap-notice-bell" data-taptap-ajax="notification" data-message-total="条新消息" type="button" data-unread="0" data-get-unread-total-url="https://www.taptap.com/ajax/notification/un-read-total" data-url="https://www.taptap.com/ajax/notification" onclick="ga('send','event','Topbar','Notification','MenuExpand')">
    <i class=""></i>
</button>
                <div class="taptap-notice-widget" id="ajaxNotifications" style="display: none;">
    <div class="notice-widget-loading" data-taptap-ajax-notification="loading">
        <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="">
    </div>
</div>
            </li>
            <li class="dropdown navbar-user">
                <a href="https://www.taptap.com/auth/login" class="img-circle avatar-wrap" rel="nofollow" role="button" aria-haspopup="true" aria-expanded="false">
                    <img src="https://img.tapimg.com/market/images/22f1196f825298281376608459bfa7fe.png" alt="">
                </a>
                <input type="hidden" value="个人中心" id="dashboard">
                <input type="hidden" value="我的关注" id="my_following">
                <input type="hidden" value="我的收藏" id="my_collections">
                <input type="hidden" value="我的订单" id="my_orders">
                <input type="hidden" value="篝火计划" id="campfire">
                <input type="hidden" value="浏览历史" id="browse_history">
                <input type="hidden" value="我的草稿" id="draft_box">
                <input type="hidden" value="开发者中心" id="developer_center">
                <input type="hidden" value="登出" id="logout">
                <input type="hidden" value="解冻账号" id="activate">
            </li>
        </ul>
                <form class="navbar-form" id="search" role="search" method="get" action="https://www.taptap.com/search">
            <div class="form-group">
              <button type="submit" class="btn btn-default">
                <i class="icon-font icon-search2"></i>
              </button>
                <input type="text" class="form-control js-emit search-input" tap-event="click:search.show,change:search.apps,keydown:search.keydown" autocomplete="off" id="search-kw" name="kw" value="" placeholder="搜索...">
            </div>
                                        <div class="taptap-search " style="display: none;">
        <div class="supports">
        <section class="history">
            <header>
                历史搜索
                <span class="clear-history">
                    <button class="js-emit" tap-event="search.clear-history" type="button">清空</button>
                </span>
            </header>
            <div class="list">
                <ul class="list-unstyled">
                    <li class="loading">
                        <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading">
                    </li>
                </ul>
            </div>
        </section>
        <section class="hot-word">
            <header>热门搜索</header>
            <div class="list">
                <ul class="list-unstyled">
                </ul>
            </div>
        </section>
        <section class="results show">
      <div class="loading">
      <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading">
    </div>
  </section>
    </div>
</div>
                    </form>
    </div>
</nav>
                        <section class="taptap-breadcrumb">
            <div class="container">
                <div class="row">
                    <ol class="breadcrumb">
                        <li><span>你的位置:</span></li>
                        <li><a href="https://www.taptap.com">首页</a></li>
                        
    <li><a href="https://www.taptap.com/developer/3505">网易游戏</a></li>
    <li class="active"><span>厂商游戏</span></li>

                    </ol>
                    <span class="breadcrumb-end"></span>
                </div>
            </div>
        </section>
        
            <div class="container">
        <div class="row">
            <div class="col-sm-12">
                <section class="app-category-list">
                    <div class="section-title">
                        <h1>厂商游戏</h1>
                    </div>
                    <div class="tab-content">
                        <div class="tab-pane active" role="tab" id="apps">
                            <div class="taptap-app-list" id="appList">
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/73048" data-taptap-url="taptap://taptap.com/app?app_id=73048&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/09ab2bd8e3896550fa9c4fbf5490515c_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/09ab2bd8e3896550fa9c4fbf5490515c_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="量子特攻" title="量子特攻" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/73048" data-taptap-url="taptap://taptap.com/app?app_id=73048&amp;style=0" title="量子特攻">
            <h4 class="flex-text">量子特攻</h4>
                            <small class="taptap-app-area">CN</small>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/rpg" data-taptap-url="taptap://taptap.com/app_tag?tag=角色扮演" class="taptap-link">角色扮演</a>
                        <span class="caption-label-rating pull-right">
                <span>6.4</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/158690" data-taptap-url="taptap://taptap.com/app?app_id=158690&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/584fa99386c9ee41762257e92ee293ae_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/584fa99386c9ee41762257e92ee293ae_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="阴阳师：百闻牌" title="阴阳师：百闻牌" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/158690" data-taptap-url="taptap://taptap.com/app?app_id=158690&amp;style=0" title="阴阳师：百闻牌">
            <h4 class="flex-text">阴阳师：百闻牌</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/card" data-taptap-url="taptap://taptap.com/app_tag?tag=卡牌" class="taptap-link">卡牌</a>
                        <span class="caption-label-rating pull-right">
                <span>8.7</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/179596" data-taptap-url="taptap://taptap.com/app?app_id=179596&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/icons/b72fbc2c9627ada665ce2644f5321c39_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/icons/b72fbc2c9627ada665ce2644f5321c39_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="风暴战争" title="风暴战争" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/179596" data-taptap-url="taptap://taptap.com/app?app_id=179596&amp;style=0" title="风暴战争">
            <h4 class="flex-text">风暴战争</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/strategy" data-taptap-url="taptap://taptap.com/app_tag?tag=策略" class="taptap-link">策略</a>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/71477" data-taptap-url="taptap://taptap.com/app?app_id=71477&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/afb4955911f8e79c2e6e2988f3923249_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/afb4955911f8e79c2e6e2988f3923249_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="迷室：往逝" title="迷室：往逝" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/71477" data-taptap-url="taptap://taptap.com/app?app_id=71477&amp;style=0" title="迷室：往逝">
            <h4 class="flex-text">迷室：往逝</h4>
                            <small class="taptap-app-area">CN</small>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/trivia" data-taptap-url="taptap://taptap.com/app_tag?tag=益智" class="taptap-link">益智</a>
                        <span class="caption-label-rating pull-right">
                <span>9.2</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/164412" data-taptap-url="taptap://taptap.com/app?app_id=164412&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/b5d3a1aacaaa3785c043877a87cc018c_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/b5d3a1aacaaa3785c043877a87cc018c_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="Disorder（测试服）" title="Disorder（测试服）" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/164412" data-taptap-url="taptap://taptap.com/app?app_id=164412&amp;style=0" title="Disorder（测试服）">
            <h4 class="flex-text">Disorder（测试服）</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/rpg" data-taptap-url="taptap://taptap.com/app_tag?tag=角色扮演" class="taptap-link">角色扮演</a>
                        <span class="caption-label-rating pull-right">
                <span>7.1</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/82719" data-taptap-url="taptap://taptap.com/app?app_id=82719&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/d76b28ca955f166015ef38cc8bcc5467_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/d76b28ca955f166015ef38cc8bcc5467_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="光·遇（测试服）" title="光·遇（测试服）" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/82719" data-taptap-url="taptap://taptap.com/app?app_id=82719&amp;style=0" title="光·遇（测试服）">
            <h4 class="flex-text">光·遇（测试服）</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/rpg" data-taptap-url="taptap://taptap.com/app_tag?tag=角色扮演" class="taptap-link">角色扮演</a>
                        <span class="caption-label-rating pull-right">
                <span>9.0</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/161629" data-taptap-url="taptap://taptap.com/app?app_id=161629&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/b5d3a1aacaaa3785c043877a87cc018c_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/b5d3a1aacaaa3785c043877a87cc018c_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="Disorder" title="Disorder" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/161629" data-taptap-url="taptap://taptap.com/app?app_id=161629&amp;style=0" title="Disorder">
            <h4 class="flex-text">Disorder</h4>
                            <small class="taptap-app-area">CN</small>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/rpg" data-taptap-url="taptap://taptap.com/app_tag?tag=角色扮演" class="taptap-link">角色扮演</a>
                        <span class="caption-label-rating pull-right">
                <span>8.0</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
                                                                    <div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/62448" data-taptap-url="taptap://taptap.com/app?app_id=62448&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/d76b28ca955f166015ef38cc8bcc5467_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/d76b28ca955f166015ef38cc8bcc5467_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt
span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
<div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/2246" data-taptap-url="taptap://taptap.com/app?app_id=2246&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/icons/4f82f2fe38bcc5b390f9755fe2e7f018_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/icons/4f82f2fe38bcc5b390f9755fe2e7f018_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="功夫熊猫3" title="功夫熊猫3" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/2246" data-taptap-url="taptap://taptap.com/app?app_id=2246&amp;style=0" title="功夫熊猫3">
            <h4 class="flex-text">功夫熊猫3</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/rpg" data-taptap-url="taptap://taptap.com/app_tag?tag=角色扮演" class="taptap-link">角色扮演</a>
                        <span class="caption-label-rating pull-right">
                <span>7.5</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
<div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/15434" data-taptap-url="taptap://taptap.com/app?app_id=15434&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/icons/f9e67343df37e518c0c3217d7326af2f_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/icons/f9e67343df37e518c0c3217d7326af2f_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="惊梦" title="惊梦" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/15434" data-taptap-url="taptap://taptap.com/app?app_id=15434&amp;style=0" title="惊梦">
            <h4 class="flex-text">惊梦</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/trivia" data-taptap-url="taptap://taptap.com/app_tag?tag=益智" class="taptap-link">益智</a>
                        <span class="caption-label-rating pull-right">
                <span>9.3</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
<div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/14493" data-taptap-url="taptap://taptap.com/app?app_id=14493&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/098b88cad34638cf3716b2f2d26c7b7d_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/098b88cad34638cf3716b2f2d26c7b7d_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="花语月" title="花语月" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/14493" data-taptap-url="taptap://taptap.com/app?app_id=14493&amp;style=0" title="花语月">
            <h4 class="flex-text">花语月</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/casual" data-taptap-url="taptap://taptap.com/app_tag?tag=休闲" class="taptap-link">休闲</a>
                        <span class="caption-label-rating pull-right">
                <span>9.4</span>
                <i></i>
            </span>
                    </span>
            </div>
</div>
<div class="taptap-app-item swiper-slide">
    <a href="https://www.taptap.com/app/26416" data-taptap-url="taptap://taptap.com/app?app_id=26416&amp;style=0" class="app-item-image taptap-link" style="background: transparent;">
        <img src="https://img.tapimg.com/market/lcs/9c0889b9241c9cdd23f2ee77c987b834_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" data-src="https://img.tapimg.com/market/lcs/9c0889b9241c9cdd23f2ee77c987b834_360.png?imageView2/1/w/256/q/40/interlace/1/ignore-error/1" alt="契约兵团" title="契约兵团" data-taptap-image="lazyLoading" class="show" style="display: block;">
    </a>
    <div class="app-item-caption">
        <a class="item-caption-title flex-text-overflow taptap-link" href="https://www.taptap.com/app/26416" data-taptap-url="taptap://taptap.com/app?app_id=26416&amp;style=0" title="契约兵团">
            <h4 class="flex-text">契约兵团</h4>
                    </a>
        <span class="item-caption-label">
            <a href="https://www.taptap.com/category/strategy" data-taptap-url="taptap://taptap.com/app_tag?tag=策略" class="taptap-link">策略</a>
                        <span class="caption-label-rating pull-right">
                <span>7.6</span>
                <i></i>
            </span>
                    </span>
            </div>
</div></div>
                                                            <section class="taptap-button-more load-more">
    <button class="btn btn-primary btn-lg" data-taptap-ajax="more" data-method="get" data-target="#appList" data-url="https://www.taptap.com/ajax/developer/apps/3505?page=2" type="button" style="display: none;">更多</button>
    <img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="" data-taptap-ajax-more="loading" style="display: none;">
</section>
                                                    </div>
                    </div>
                </section>
            </div>
        </div>
    </div>

                            <footer class="footer">
    <div class="container">
        <div class="row">
            <div class="col-sm-12 clearfix">
                <div class="pull-right">
                    <p>Contact Us</p>
                    <ul class="list-inline">
                        <li>
                            <a class="icon-font ic_facebook" href="https://www.facebook.com/gametaptap/" target="_blank" title="Facebook" rel="nofollow"></a>
                        </li>
                        <li>
                            <span class="icon-font ic_wechat" title="微信"></span>
                            <div>
                                <span class="thumbnail">
                                    <img src="https://img.tapimg.com/market/images/c4bf2701e3ee9993e1ee0b8222480a35.jpg" alt="">
                                </span>
                            </div>
                        </li>
                        <li>
                            <span class="icon-font ic_qq" title="QQ"></span>
                            <div>
                                <span class="thumbnail">官方QQ群: 780255342</span>
                            </div>
                        </li>
                        <li>
                            <a class="icon-font ic_zhihu" href="https://zhuanlan.zhihu.com/taptap" target="_blank" title="知乎" rel="nofollow"></a>
                        </li>
                        <li>
                            <a class="icon-font ic_sina" href="http://weibo.com/taptapgames" target="_blank" title="微博" rel="nofollow"></a>
                        </li>
                        <li>
                            <span class="icon-font ic_mail" title="邮箱"></span>
                            <div>
                                <span class="thumbnail">
                                    合作邮箱: <a href="mailto:cooperation@taptap.com" rel="nofollow">cooperation@taptap.com</a>
                                </span>
                            </div>
                        </li>
                    </ul>
                                                                        <p>官方活动</p>
                                            <div class="events-link">
                        <span class="link">
                            <a href="https://www.taptap.com/events/3rd-anniversary" rel="nofollow" onclick="ga('send','event','bottom-entry','click','thirdAnniversary');sa.click({position: '页脚'}, event)">TapTap 三周年</a>
                        </span>
                        <span class="link">
                            <a href="https://www.taptap.com/campfire" rel="nofollow" onclick="ga('send','event','bottom-entry','click','campfire');sa.click({position: '页脚'}, event)">篝火计划</a>
                        </span>
                        <span class="link">
                            <a href="https://www.taptap.com/events/3rd-anniversary/doodle" rel="nofollow" onclick="ga('send','event','bottom-entry','click','doodle2019');sa.click({position: '页脚'}, event)">涂鸦大赛</a>
                        </span>
                        <span class="link">
                            <a href="https://www.taptap.com/game-awards2018" rel="nofollow" onclick="ga('send','event','bottom-entry','click','gameAwards2018');sa.click({position: '页脚'}, event)">2018年度游戏大赏</a>
                        </span>
                    </div>
                                                        </div>
                <div class="footer-left">
                    <div class="footer-left-header">
                        <span class="left-header-logo">
                            <img src="https://assets.tapimg.com/img/ic_logocn@3x.png?20190610" alt="TapTap 中国" title="TapTap 中国">
                        </span>
                        <div class="dropdown">
                                                                                                                <button id="regionSelect" type="button" class="btn btn-link" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                                中文 (简体)
                                <span class="caret"></span>
                            </button>
                            <ul class="dropdown-menu" aria-labelledby="regionSelect">
                                <li><span class="dropdown-tips">选择语言</span></li>
                                                                    <li class="active">
                                            <a href="https://www.taptap.com/set-region?region=cn" class="js-http-post" rel="nofollow">中文 (简体)</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=tw" class="js-http-post" rel="nofollow">中文 (繁體)</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=us" class="js-http-post" rel="nofollow">English</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=jp" class="js-http-post" rel="nofollow">日本語</a>
                                    </li>
                                                                    <li>
                                            <a href="https://www.taptap.com/set-region?region=kr" class="js-http-post" rel="nofollow">한국어</a>
                                    </li>
                                                            </ul>
                        </div>
                        <p class="links">
                            <span class="link">
                                <a href="https://www.taptap.com/developer" rel="nofollow">开发者中心</a>
                            </span>
                                                            <span class="link">
                                    <a href="https://www.taptap.com/developer/developer-distribution-agreement" rel="nofollow">开发者协议</a>
                                </span>
                                                        <span class="link">
                                <a href="https://www.taptap.com/ads" rel="nofollow">广告投放</a>
                            </span>
                            <span class="link">
                                <a href="https://www.taptap.com/about-us" rel="nofollow">关于我们</a>
                            </span>
                            <span class="link">
                                <a href="https://www.taptap.com/hr" rel="nofollow">加入我们</a>
                            </span>
                                                        <span class="link">
                                <a href="https://www.taptap.com/user-verification" rel="nofollow">用户认证</a>
                            </span>
                                                    </p>
                    </div>
                    <p>Discover Superb Games.</p>
                    <span>
                        <span>Copyright © 2019 <a href="https://www.taptap.com">TapTap</a>. All rights Reserved.</span>
                        <br>
                        <span>适龄提示: 本公司产品适合 10 周岁以上玩家使用</span>
                        <span>&nbsp;<a href="https://www.taptap.com/taptapjh" target="_blank" rel="nofollow">未成年人家长监护</a>&nbsp;&nbsp;                            <a href="https://www.taptap.com/privacy-policy" rel="nofollow">隐私政策</a>&nbsp;&nbsp;
                            <a href="https://www.taptap.com/copyright" rel="nofollow">侵权投诉</a>                         </span>
                        <br>
                                                <span>
                            <a href="http://www.beian.miit.gov.cn/" target="_blank" rel="nofollow">沪ICP备16012525号-1</a>&nbsp;&nbsp;
                            <a href="/license/www.html">沪网文(2019)3544-255号&nbsp;&nbsp;</a>
                        </span>
                        <br>
                                                <span class="manage">经营许可证编号: 沪B2-20170322</span>易玩（上海）网络科技有限公司
                        <br>
                        <span>公司地址: 上海市静安区万荣路 700 号 A3 202</span>
                    </span>
                </div>
            </div>
                            <div class="col-sm-12 clearfix">
                    <span class="record-filing">
                        <a target="_blank" href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=31010402003255" rel="nofollow">
                            <img src="https://img.tapimg.com/market/images/d0289dc0a46fc5b15b3363ffa78cf6c7.png">
                            <p>沪公网安备 31010402003255号</p>
                        </a>
                        <a target="_blank" href="http://sq.ccm.gov.cn:80/ccnt/sczr/service/business/emark/toDetail/35EE6340BAC97151E0530140A8C0E25A" rel="nofollow">
                            <img src="https://img.tapimg.com/market/images/d839a60d8749eca93b9ca669583e65f4.png">
                            <p>互联网文化经营单位</p>
                        </a>
                        <a target="_blank" href="http://www.shjbzx.cn/" class="report" title="上海市互联网违法和不良信息举报中心" rel="nofollow">
                            <img src="https://img.tapimg.com/market/images/205fb1dc7c6c602e57c1b8e6477529d4.png">
                        </a>
                                            </span>
                </div>
                    </div>
    </div>
</footer>
        
        
                                    <section class="modal fade taptap-modal global-tip-modal" tabindex="-1" role="dialog" id="global-tip-modal">
    <div class="modal-dialog">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
                <h4 class="modal-title" data-default-text="提示">提示</h4>
            </div>
            <div class="modal-body">
                <p></p>
            </div>
            <div class="modal-footer">
                <button class="btn btn-primary" data-default-text="确定">确定</button>
                <button class="btn btn-default" data-dismiss="modal" data-default-text="取消">取消</button>
            </div>
        </div>
    </div>
</section>
    <div class="modal fade taptap-modal taptap-alert taptap-alert-success" tabindex="-1" role="dialog" id="operation-state-modal">
  <div class="modal-dialog">
    <div class="modal-content">
      <div class="modal-body">
        <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
        <div class="alert-logo success">
          <span></span>
        </div>
        <p class="alert-message-title"></p>
        <p class="alert-message single-line">成功</p>
        <div class="html-render"></div>
              </div>
    </div>
  </div>
</div>
    <div class="taptap-simple-alert" id="simpleAlertModal">
  <button type="button"><span aria-hidden="true">×</span></button>
  <span class="alert-logo fail">
    <i class="icon-font icon-error"></i>
    <p class="alert-message">trans('interface.word.success')</p>
  </span>
</div>
    <section class="taptap-button-top" data-taptap-widgets="container" data-taptap-go="top" style="display: block;">
    <i class="icon-font icon-stick"></i>
</section>
                <section class="taptap-bottom-banner collapse" id="bottomBanner">
    <div class="container">
        <div class="row">
            <div class="col-sm-12 clearfix">
                <div class="bottom-banner-left">
                    <img src="https://img.tapimg.com/market/images/dcaacad6231ac7003cf1b62b6643c450.png" alt="">
                </div>
                <div class="bottom-banner-center">
                    <ul class="list-unstyled">
                                                <li>
                            <span></span>
                            <p>一天一款全球精品游戏推荐，活跃的玩家交流社区</p>
                        </li>
                                                <li>
                            <span></span>
                            <p>只收录官方包，不联运，支持安卓正版游戏购买</p>
                        </li>
                                                <li>
                            <span></span>
                            <p> 倡导真实评分评价，排行榜单来自玩家真实反馈</p>
                        </li>
                                            </ul>
                    <p>
                        <span>TapTap</span>
                        <br>
                        发现好游戏
                    </p>
                </div>
                <div class="bottom-banner-right">
                    <button class="close" type="button" data-toggle="collapse" data-target="#bottomBanner" data-taptap-cookie-set="bottom_banner_hidden" data-days="365" data-value="1">
                        <i class="taptap-icon icon-times"></i>
                    </button>
                    <div class="banner-right-btns">
                        <button class="btn btn-default taptap-button-hollow" data-taptap-modal="qrcode">
                            二维码下载
                            <span data-taptap-qrcode="generate" data-url="https://d.taptap.com/latest"><canvas width="100" height="100"></canvas></span>
                        </button>
                        <a href="https://d.taptap.com/latest" class="btn btn-success" onclick="ga('send', 'event', 'Client', 'BottombarDownload');sa.perform({action: 'Download', type: 'BottomBanner'});" rel="nofollow">
                            <span class="desktop">免费下载</span>
                            <span class="mobile">下载</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div>
</section>
                    <section class="modal fade taptap-modal login-tips" tabindex="-1" role="dialog" aria-labelledby="loginTipsModal" id="loginTipsModal">
    <div class="modal-dialog">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
                <h4 class="modal-title">温馨提示</h4>
            </div>
            <div class="modal-body">
                <p>请先<a href="/auth/login" rel="nofollow">登录</a>后，再进行操作</p>
            </div>
        </div>
    </div>
</section>                <section class="modal fade taptap-modal login-form" tabindex="-1" role="dialog" aria-labelledby="loginFormModal" id="loginFormModal">
    <div class="modal-dialog">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
                <h4 class="modal-title"></h4>
            </div>
            <div class="modal-body auth-main">
                <div class="auth-main-body login">

                </div>

            </div>
        </div>
    </div>
</section>
        <section class="modal fade taptap-modal phone-captcha-modal" tabindex="-1" role="dialog" aria-labelledby="phoneCaptcha" id="phoneCaptcha">
    <div class="modal-dialog ">
        <div class="modal-content">
            <div class="modal-header">
                <button type="button" class="close" data-dismiss="modal" aria-label="Close">
                    <span aria-hidden="true">×</span>
                </button>
            </div>
            <div class="modal-content">
                <h5>请输入短信验证码</h5>
                                    <div id="phone-captcha" class="phone-captcha">
                        <input type="text" maxlength="1" autofocus="" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                        <input type="text" maxlength="1" required="" autocomplete="off">
                    </div>
                                <div class="loading"><img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading"></div>
                <div class="error"></div>
            </div>
            <div class="modal-footer">
                <div class="code-tip" data-taptap-has-send="true">
                    <p>短信验证码已发送至<span id="phone-number">+86xxxxxxxxxxxx</span></p>
                    <p><span id="count" class="count">59</span>&nbsp;秒后可重新发送</p>
                </div>
                <div class="code-tip" data-taptap-has-send="false">
                    <p class="send-again-container">
                        <span class="send-loading"><img src="https://img.tapimg.com/market/images/0e6e0f46d7504242302bc8055ad9c8c2.gif" alt="loading"></span>
                        <span id="send-again" class="count" tap-event="sendPhoneCaptcha">重新发送</span>
                    </p>
                </div>
            </div>
        </div>
    </div>
</section>
            
            <div class="modal fade taptap-modal user-certification" tabindex="-1" role="dialog" id="verifyIdcardModal">
  <div class="modal-dialog">
    <div class="modal-content">
      <form action="" method="post" id="verifyIdcardForm">
        <input type="hidden" name="_token" value="AVT9QB4LcFIvuCyAUSfFxtA1Ad77K2wFcaaAwGav">
        <div class="modal-header">
          <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
          <h4 class="modal-title">实名信息提交</h4>
        </div>
        <div class="modal-body">
          <div class="common-form-fields">
            <div class="common-form-basic-title">
              <h3><span>真实姓名</span></h3>
            </div>
            <p class="common-field">
              <input type="text" name="real_name" class="common-form-text" id="real-name">
            </p>
            <div class="common-form-basic-title">
              <h3><span>身份证号码</span></h3>
            </div>
            <p class="common-field">
              <input type="text" name="idcard" class="common-form-text" id="idcard-number">
            </p>
          </div>
          <p class="note">*请使用真实姓名及有效身份证号码进行实名信息提交<br>*身份信息提交后不可进行修改<br>*有意填写非本人身份信息者，被发现将对账号进行封禁处理<br>*如有疑问，可联系 TapTap 客服邮箱：kefu@taptap.com</p>
        </div>
        <div class="modal-footer">
          <button type="submit" class="btn btn-primary" data-url="https://www.taptap.com/ajax/profile/idcard" id="verify-submit">提交</button>
                  </div>
      </form>
    </div>
  </div>
</div>
                <script>
    (function (i, s, o, g, r, a, m) {
        i['GoogleAnalyticsObject'] = r;
        i[r] = i[r] || function () {
            (i[r].q = i[r].q || []).push(arguments)
        }, i[r].l = 1 * new Date();
        a = s.createElement(o),
            m = s.getElementsByTagName(o)[0];
        a.async = 1;
        a.src = g;
        m.parentNode.insertBefore(a, m)
    })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');

            ga('create', 'UA-73963350-1', 'auto');
    
    var browserName = "Other";
    var ua = window.navigator.userAgent;
    browserRegExp = {
        iOSSDK: /TapTapiOSSDK/,
        AndroidSDK: /TapTapAndroidSDK/,
        Sogou: /SE\s2\.X|SogouMobileBrowser/,
        Explorer2345: /2345Explorer|2345chrome|Mb2345Browser/,
        Liebao: /LBBROWSER/,
        Wechat: /MicroMessenger/,
        QQBrowser: /QQBrowser/,
        Baidu: /BIDUBrowser|baidubrowser|BaiduHD/,
        UC: /UBrowser|UCBrowser|UCWEB/,
        MiuiBrowser: /MiuiBrowser/,
        MobileQQ: /Mobile\/\w{5,}\sQQ\/(\d+[\.\d]+)/,
        Shoujibaidu: /baiduboxapp/,
        SamsungBrowser: /samsungbrowser/,
        Firefox: /Firefox/,
        Maxthon: /Maxthon/,
        Se360: /360SE/,
        Ee360: /360EE/,
        TheWorld: /TheWorld/,
        Weibo: /__weibo__/,
        NokiaBrowser: /NokiaBrowser/,
        Opera: /Opera|OPR\/(\d+[\.\d]+)/,
        Edge: /Edge/,
        QQLive: /QQLive(HD)?Browser/,
        Letv: /LetvClient/,
        Youku: /Youku/,
        AndroidBrowser: /Android.*Mobile\sSafari|Android\/(\d[\.\d]+)\sRelease\/(\d[\.\d]+)\sBrowser\/AppleWebKit(\d[\.\d]+)/i,
        IE: /Trident|MSIE/,
        TouTiao: /NewsArticle/,
        Chrome: /Chrome|CriOS/,
        Safari: /Version[|\/]([\w.]+)(\s\w.+)?\s?Safari|like\sGecko\)\sMobile\/\w{3,}$/,
    };

    if (window.tapEnv && window.tapEnv.browser && window.tapEnv.browser.inApp === true) {
        browserName = "InApp";
    } else {
        for (var i in browserRegExp) {
            if (browserRegExp[i].exec(ua)) {
                browserName = i;
                break;
            }
        }
    }

    if(window.tapEnv && window.tapEnv.user && window.tapEnv.user.id) {
        ga('set', 'dimension4', 'login');
    } else {
        ga('set', 'dimension4', 'guest');
    }

    if (browserName === "Other") {
        ga('set', 'dimension2', browserName + "-" + ua);
    } else {
        ga('set', 'dimension1', browserName);
    }

    ga('send', 'pageview');
</script>

<script>
(function (para) {
  var p = para.sdk_url, n = para.name, w = window, d = document, s = 'script', x = null, y = null;
  w['sensorsDataAnalytic201505'] = n;
  w[n] = w[n] || function (a) {
    return function () {
      (w[n]._q = w[n]._q || []).push([a, arguments]);
    }
  };
  var ifs = ['track', 'quick', 'register', 'registerPage', 'registerOnce', 'trackSignup', 'trackAbtest', 'setProfile', 'setOnceProfile', 'appendProfile', 'incrementProfile', 'deleteProfile', 'unsetProfile', 'identify', 'login', 'logout', 'trackLink', 'clearAllRegister', 'getAppStatus'];
  for (var i = 0; i < ifs.length; i++) {
    w[n][ifs[i]] = w[n].call(null, ifs[i]);
  }
  if (!w[n]._t) {
    x = d.createElement(s), y = d.getElementsByTagName(s)[0];
    x.async = 1;
    x.src = p;
    x.setAttribute('charset', 'UTF-8');
    y.parentNode.insertBefore(x, y);
    w[n].para = para;
  }
})({
  sdk_url: 'https://assets.tapimg.com/scripts/sensorsdata.min.js',
  heatmap_url: 'https://assets.tapimg.com/scripts/heatmap.min.js',
  name: 'sensorsSDK',
  web_url: 'https://sa.taptap.com/',
  server_url: 'https://sd.taptap.com/sa',
  show_log: false
});
window.sa = {
  post: function (props) {
    sensorsSDK.track('WebPost', props);
  },
  perform: function (props) {
    sensorsSDK.track('WebPerform', props);
  },
  click: function (props, event) {
    var target = event.target ? event.target : event.srcElement;
    target = target.closest('a');
    props.target_url = target.href;
    props.target_path = target.pathname
    sensorsSDK.track('$WebClick', props);
  },
  login: function (props) {
    sensorsSDK.track('WebLogin', props);
  }
};
(function () {
  var registerProps = {
    url: Tap.URI(location.href).pure().toString(),
    referer: document.referrer,
    path: location.pathname
  }
  if (Tap.browser.is('inApp')) {
    registerProps['client'] = Tap.env('browser.inAppPn', 'Unknown');
  }
  sensorsSDK.registerPage(registerProps);

  var user_id = $('meta[name=user_id]').attr('content');
  if (user_id) {
    sensorsSDK.login(user_id)
  } else {
    sensorsSDK.logout();
  }
  sensorsSDK.quick('autoTrack');
})();
</script>


<script>
        (function () {
        var tapUri = new Tap.URI();

        var bp = document.createElement('script');
        var curProtocol = window.location.protocol.split(':')[0];
        if (curProtocol === 'https') {
            bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
        }
        else {
            bp.src = 'http://push.zhanzhang.baidu.com/push.js';
        }
        var s = document.getElementsByTagName("script")[0];
        s.parentNode.insertBefore(bp, s);

                        var referrer = document.referrer;
        var bdUri;
        var bdsem;
        if (referrer) {
            bdUri = new Tap.URI(referrer);
            bdsem = bdUri.parse();
        }

        if ((tapUri.get('utm_source') == 'baidu' || tapUri.get('utm_medium') == 'sem' || (bdsem !== undefined && bdsem['path'] == 'baidu.php'))
            && Tap.browser.is('mobile')) {

            var state = {
                title: 'TapTap',
                url: '#'
            };

            window.history.pushState(state, "TapTap", '#');
            window.addEventListener('popstate', function popstate(e) {
                let newUri = new Tap.URI();
                if (newUri.get('utm_source') == 'baidu' || newUri.get('utm_medium') == 'sem') {
                    window.removeEventListener('popstate', popstate, false);
                    location.assign('/');
                }
            }, false);


        }
    })();
    </script>
            

</body>'''

# %%
page_html = bs.BeautifulSoup(text2) 
news_containers = page_html.find_all("div", class_= "taptap-app-list") 
titles = []
urls = []
gametypes = []
scores = []

for container in news_containers:
    for link in container.find_all("a", class_="item-caption-title flex-text-overflow taptap-link"): 
        titles.append(link.text.strip()) 
        urls.append(link.get("href")) 
        
    for gametype in container.find_all("span", class_="item-caption-label"):
        gametypes.append(gametype.a.string)
        
    for score in container.find_all("span", class_="caption-label-rating pull-right"):
        scores.append(score.span.string)
        
datatop2 = {
    "titles":titles,
    "urls":urls,
    "gametypes":gametypes,
    "scores":scores
}

import pandas as pd 
Top2_NetEase = pd.DataFrame.from_dict(datatop2, orient ="index").transpose()
Top2_NetEase.to_csv("Top2_NetEase.csv")

# %%
Top2_NetEase
# Out:
#                             titles                               urls  \
# 0                         量子特攻\nCN   https://www.taptap.com/app/73048
# 1                          阴阳师：百闻牌  https://www.taptap.com/app/158690
# 2                             风暴战争  https://www.taptap.com/app/179596
# 3                        迷室：往逝\nCN   https://www.taptap.com/app/71477
# 4                    Disorder（测试服）  https://www.taptap.com/app/164412
# 5                         光·遇（测试服）   https://www.taptap.com/app/82719
# 6                     Disorder\nCN  https://www.taptap.com/app/161629
# 7                          光·遇\nCN   https://www.taptap.com/app/62448
# 8                         非人学园\nCN   https://www.taptap.com/app/64403
# 9                       堡垒前线：破坏与创造  https://www.taptap.com/app/165139
# 10                        海島紀元\nTW  https://www.taptap.com/app/161584
# 11                     战舰世界闪击战\nCN   https://www.taptap.com/app/91972
# ...
